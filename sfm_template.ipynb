# %% [markdown]
# # Structure from motion

# %% [markdown]
# ## Methods

# %% [markdown]
# SFM was performed, which involved collecting feature data using Open cv's SIFT feature detector for randomly selected frames from a video. Then, two-view reconstruciton was performed along with optimization of the calculated pose to reduce the projection error. Then, resectioning was performed in order to add more features from other frames to the list of matched features where the final pose estimates in this step were also optimzed to keep the propigation of pixel errors as low as possible as resectioning was performed repeatedly.

# %% [markdown]
# RANSAC was added to both the two view reconstruction and resectioning. In the two view construction case, eight points were sampled and the essential matrix which was calculated using the sample points which gave the most epipolar distances below a chosen threshold over a chosen number of recalculations is chosen. In the resectioning case, six points are selected and the largest number of reprojection errors below a chosen threshold are chosen. The reprojection error is the difference between the points in the frame that is being resection and the estimated points using the pose estimate that is created during resectioning.

# %% [markdown]
# ## Results

# %% [markdown]
# The 'matching_threshold' was increased to 0.6 because at 0.5 not enough points were being generated where the number of inlers for resectioning would 'run out' in 5 additions of frames from the video; however if using 0.6 as the trehshold, it was possible to perform at least 7 cycles. The reason why I say 'at least' is becasue after that, each addition of a new image would take about 30 minutes to complete and that did not feel like a good use of time.

# %% [markdown]
# The number of iterations in the RANSAC implementation for resectioning needed to be increased because the pixel errors for the added image would be too spread out and this was true for a range of different images; this was also tested over many iterations that used different seeds. After increasing the number of iterations, the pixel error was reduced more consistantly over a range testing cycles with different seeds.

# %% [markdown]
# 'results.rrd', contains the point cloud data over seven images and can be viewed by opening the file in Rerun.io.

# %% [markdown]
# ## Future Work

# %% [markdown]
# I would like to test this code with a different camera which I know I will have to do for the project.

# %% [markdown]
# I want to see if I can use the optomizer in C++ because the optimization steps take a very long time; however I do not know how to code in C++ so no better time to learn than the present.

# %% [markdown]
# Import everything *except* our sfm library.

# %%
# Import symforce for the sole purpose of setting the value
# of epsilon, which must be done first and exactly once.
import symforce
symforce.set_epsilon_to_symbol()

import importlib
from pathlib import Path
import numpy as np
import secrets
import cv2
import matplotlib.pyplot as plt
from matplotlib.patches import ConnectionPatch
import rerun as rr
from uuid import uuid4

# %% [markdown]
# Import our sfm library. (Re-evaluate this cell if you make changes to the library.)

# %%
import sfm
importlib.reload(sfm)
# Out:
# <module 'sfm' from '/home/amirn/Documents/UIUC_SP_24/AE_598/ae598-3dv/homework/Project/sfm.py'>

# %% [markdown]
# Choose parameter values.

# %%
# When reading video frames
frames_to_skip = 30

# When matching (max threshold for ratio test)
matching_threshold = 0.6

# When deciding if triangulated points are invalid
max_reprojection_err = 0.75

fx = 1641.230773199689
fy = 1641.597139080483
cx = 530.846475337206
cy = 973.6379239646022

# Camera matrix
K = np.array([
    [fx, 0.0,cx],
    [0.0, fy, cy],
    [0.0, 0.0, 1.0],
])

# %% [markdown]
# Create random number generator.

# %%
seed = secrets.randbits(32)
print(f'seeding RNG with {seed}')
rng = np.random.default_rng(seed)
# Out:
# seeding RNG with 574728658

# %% [markdown]
# Initialize 3D visualizer (should open the rerun application if that isn't already open).

# %%
# Create recording with unique ID
rr.init('my_sfm', recording_id=uuid4(), spawn=True)

# Initialize a time sequence
rr.set_time_seconds('stable_time', 0)

# Make view coordinates consistent with camera frames (z forward, x right, y down)
rr.log('/results', rr.ViewCoordinates.RDF, timeless=True)
# Out:
# [2024-04-28T03:42:20Z INFO  egui_wgpu] There were 2 available wgpu adapters: {backend: Vulkan, device_type: IntegratedGpu, name: "AMD Radeon Vega 3 Graphics (RADV RAVEN)", driver: "radv", driver_info: "Mesa 23.0.4-0ubuntu1~22.04.1", vendor: 0x1002, device: 0x15D8}, {backend: Vulkan, device_type: Cpu, name: "llvmpipe (LLVM 15.0.7, 256 bits)", driver: "llvmpipe", driver_info: "Mesa 23.0.4-0ubuntu1~22.04.1 (LLVM 15.0.7)", vendor: 0x10005}
# [2024-04-28T03:42:20Z INFO  tracing::span] perform;
# [2024-04-28T03:42:20Z INFO  zbus::handshake] write_command; command=Auth(Some(External), Some([49, 48, 48, 48]))
# [2024-04-28T03:42:20Z INFO  tracing::span] read_command;
# [2024-04-28T03:42:20Z INFO  zbus::handshake] write_command; command=NegotiateUnixFD
# [2024-04-28T03:42:20Z INFO  tracing::span] read_command;
# [2024-04-28T03:42:20Z INFO  zbus::handshake] write_command; command=Begin
# [2024-04-28T03:42:20Z INFO  tracing::span] socket reader;
# [2024-04-28T03:42:20Z INFO  tracing::span] perform;
# [2024-04-28T03:42:20Z INFO  zbus::handshake] write_command; command=Auth(Some(External), Some([49, 48, 48, 48]))
# [2024-04-28T03:42:20Z INFO  tracing::span] read_command;
# [2024-04-28T03:42:20Z INFO  zbus::handshake] write_command; command=NegotiateUnixFD
# [2024-04-28T03:42:20Z INFO  tracing::span] read_command;
# [2024-04-28T03:42:20Z INFO  zbus::handshake] write_command; command=Begin
# [2024-04-28T03:42:20Z INFO  tracing::span] socket reader;
# [2024-04-28T03:42:20Z INFO  zbus::connection] {}; obj_server_task_name="ObjectServer task"
# [2024-04-28T03:42:20Z INFO  zbus::object_server] dispatch_message; msg=Msg { type: MethodCall, sender: UniqueName(Str(Borrowed(":1.1"))), path: ObjectPath("/org/a11y/atspi/accessible/root"), iface: InterfaceName(Str(Borrowed("org.freedesktop.DBus.Properties"))), member: MemberName(Str(Borrowed("Set"))), body: Signature("ssv") }
# [2024-04-28T03:42:20Z INFO  zbus::object_server] dispatch_method_call; msg=Msg { type: MethodCall, sender: UniqueName(Str(Borrowed(":1.1"))), path: ObjectPath("/org/a11y/atspi/accessible/root"), iface: InterfaceName(Str(Borrowed("org.freedesktop.DBus.Properties"))), member: MemberName(Str(Borrowed("Set"))), body: Signature("ssv") }
# [2024-04-28T03:42:20Z INFO  zbus::object_server] dispatch_method_call_try; msg=Msg { type: MethodCall, sender: UniqueName(Str(Borrowed(":1.1"))), path: ObjectPath("/org/a11y/atspi/accessible/root"), iface: InterfaceName(Str(Borrowed("org.freedesktop.DBus.Properties"))), member: MemberName(Str(Borrowed("Set"))), body: Signature("ssv") }
# [2024-04-28T03:42:20Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:42:20Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:42:20Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default

# %% [markdown]
# Load images from video.

# %%
# Specify filename
video_filename = Path('chair.mp4')

# Create a video reader
video_src = cv2.VideoCapture(str(video_filename))

# Get frame count and frames per second
frame_count = int(video_src.get(cv2.CAP_PROP_FRAME_COUNT))
frames_per_second = video_src.get(cv2.CAP_PROP_FPS)

# Read frames
views = []
for i_frame in range(0, frame_count, frames_to_skip):
    video_src.set(cv2.CAP_PROP_POS_FRAMES, i_frame)
    success, frame = video_src.read()
    assert(success)
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # img = edgy_image(img)
    views.append({
        'frame_id': i_frame,
        'img': img,
        'R_inB_ofA': None,
        'p_inB_ofA': None,
    })
print(f'read {len(views)} images from video')
# Out:
# [2024-04-28T03:42:20Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:42:20Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Text
# [2024-04-28T03:42:20Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Text
# [2024-04-28T03:42:20Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# read 8 images from video

# %% [markdown]
# Detection.

# %%
# Create a SIFT feature detector
sift = cv2.SIFT_create()

# Apply detector to find keypoints (pts) and descriptors (desc) in each image
for view in views:
    pts, desc = sift.detectAndCompute(image=view['img'], mask=None)
    view['pts'] = [
        {
            'pt2d': np.array(pt.pt),
            'track': None,
        }
        for pt in pts
    ]
    view['desc'] = desc
# Out:
# [2024-04-28T03:42:22Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default

# %% [markdown]
# ## Initialize with two-view reconstruction

# %% [markdown]
# ### Get initial guess

# %% [markdown]
# Apply matcher.

# %%
matches = sfm.get_good_matches(views[0]['desc'], views[1]['desc'], threshold=matching_threshold)
print(f'found {len(matches)} good matches')
# Out:
# found 2280 good matches

# %% [markdown]
# Store results.

# %%
tracks = []
for match in matches:
    track = {
        'p_inA': None,
        'valid': True,
        'matches': [
            {'view_id': 0, 'feature_id': match.queryIdx},
            {'view_id': 1, 'feature_id': match.trainIdx},
        ]
    }
    tracks.append(track)
    views[0]['pts'][match.queryIdx]['track'] = track
    views[1]['pts'][match.trainIdx]['track'] = track

# %%
tracks[0].keys()
tracks[0]['matches']
# Out:
# [{'view_id': 0, 'feature_id': 24865}, {'view_id': 1, 'feature_id': 20480}]

# %% [markdown]
# Get image coordinates of matches.

# %%
# Create a, b
a = []
b = []
for m in matches:
    a.append(views[0]['pts'][m.queryIdx]['pt2d'])
    b.append(views[1]['pts'][m.trainIdx]['pt2d'])
a = np.array(a)
b = np.array(b)

# %% [markdown]
# Visualize all good matches.

# %%
# Create figure
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))

# Show images
ax1.imshow(views[0]['img'], cmap='gray')
ax2.imshow(views[1]['img'], cmap='gray')

# Show matches
for a_i, b_i in zip(a, b):
    fig.add_artist(
        ConnectionPatch(
            a_i, b_i, 
            'data', 'data',
            axesA=ax1, axesB=ax2,\
            color='red',
            connectionstyle='arc3, rad=0.',
            linewidth=0.5,
        )
    )
    # - Draw red dot at each keypoint
    ax1.plot(a_i[0], a_i[1], 'r.', markersize=2)
    ax2.plot(b_i[0], b_i[1], 'r.', markersize=2)

plt.show()

# %% [markdown]
# Do reconstruction.

# %%
# Estimate essential matrix
E, num_inliers, mask = sfm.getE(a, b, K, rng, threshold=2e-3, num_iters=1000)
print(f'found {num_inliers} inliers')

# Decompose essential matrix to estimate pose and to triangulate points
R_inB_ofA, p_inB_ofA, p_inA = sfm.decomposeE(a, b, K, E)
# Out:
# found 2264 inliers

# %% [markdown]
# Store results.

# %%
# Store pose estimates
views[0]['R_inB_ofA'] = np.eye(3)
views[0]['p_inB_ofA'] = np.zeros(3)
views[1]['R_inB_ofA'] = R_inB_ofA
views[1]['p_inB_ofA'] = p_inB_ofA

# Always make sure zipped lists are the same length
assert(len(tracks) == len(p_inA))

# Store the position of the point corresponding to each track
for track, p_inA_i in zip(tracks, p_inA):
    track['p_inA'] = p_inA_i

# %% [markdown]
# Show results

# %%
sfm.show_results(views, tracks, K)
# Out:
# POSE ESTIMATES
#  [R_inA_ofB0, p_inA_ofB0] = [[    1.0000     0.0000     0.0000     0.0000]
#                              [    0.0000     1.0000     0.0000     0.0000]
#                              [    0.0000     0.0000     1.0000     0.0000]]
#  [R_inA_ofB1, p_inA_ofB1] = [[    0.9999    -0.0123     0.0026    -0.0167]
#                              [    0.0123     0.9999     0.0003     0.4846]
#                              [   -0.0026    -0.0002     1.0000     0.8746]]
#
# REPROJECTION ERRORS
#  Image  0 ( 2280 points) : (mean, std, max, min) = (  2.43,  52.57, 2030.49,   0.00)
#  Image  1 ( 2280 points) : (mean, std, max, min) = ( 43.12, 1993.29, 95191.33,   0.00)

# %% [markdown]
# Copy results. If you want to start again from here, do the following:
#
# ```python
# views, tracks = sfm.copy_results(views_1_ini, tracks_1_ini)
# ```

# %%
views_1_ini, tracks_1_ini = sfm.copy_results(views, tracks)

# %% [markdown]
# ### Optimize

# %% [markdown]
# Create initial values, factors, and optimized keys.

# %%
optimizer, initial_values = sfm.get_optimizer(views, tracks, K)
# Out:
# Iterate over 8 views:
#  T_inB0_ofA has an initial value
#  T_inB1_ofA has an initial value and is an optimized key
# T_inB1_ofA has an sf_scale_residual factor
# Iterate over 2280 tracks:
#  track 0:
#   track_0_p_inA has an initial value and is an optimized key
#   track_0_b_0 has an initial value and an sf_projection_residual factor
#   track_0_b_1 has an initial value and an sf_projection_residual factor
#
#  ...
#
#  track 2279:
#   track_2279_p_inA has an initial value and is an optimized key
#   track_2279_b_0 has an initial value and an sf_projection_residual factor
#   track_2279_b_1 has an initial value and an sf_projection_residual factor

# %% [markdown]
# Create and run optimizer.

# %%
result = optimizer.optimize(initial_values)
assert(result.status == symforce.opt.optimizer.Optimizer.Status.SUCCESS)
# Out:
# [2024-04-27 22:44:50.952] [info] LM<sym::Optimize> [iter    0] lambda: 1.000e+00, error prev/linear/new: 1285.649/0.000/1191.175, rel reduction: 0.07348
# [2024-04-27 22:44:59.038] [info] LM<sym::Optimize> [iter    1] lambda: 1.000e-01, error prev/linear/new: 1191.175/0.000/1079.851, rel reduction: 0.09346
# [2024-04-27 22:45:06.395] [info] LM<sym::Optimize> [iter    2] lambda: 1.000e-02, error prev/linear/new: 1079.851/0.000/1038.860, rel reduction: 0.03796
# [2024-04-27 22:45:14.232] [info] LM<sym::Optimize> [iter    3] lambda: 1.000e-03, error prev/linear/new: 1038.860/0.000/1028.784, rel reduction: 0.00970
# [2024-04-27 22:45:23.836] [info] LM<sym::Optimize> [iter    4] lambda: 1.000e-04, error prev/linear/new: 1028.784/0.000/1020.166, rel reduction: 0.00838
# [2024-04-27 22:45:35.434] [info] LM<sym::Optimize> [iter    5] lambda: 1.000e-05, error prev/linear/new: 1020.166/0.000/990.542, rel reduction: 0.02904
# [2024-04-27 22:45:43.318] [info] LM<sym::Optimize> [iter    6] lambda: 1.000e-06, error prev/linear/new: 990.542/0.000/939.610, rel reduction: 0.05142
# [2024-04-27 22:45:52.084] [info] LM<sym::Optimize> [iter    7] lambda: 1.000e-07, error prev/linear/new: 939.610/0.000/923.881, rel reduction: 0.01674
# [2024-04-27 22:45:59.906] [info] LM<sym::Optimize> [iter    8] lambda: 1.000e-08, error prev/linear/new: 923.881/0.000/925.289, rel reduction: -0.00152
# [2024-04-27 22:46:07.721] [info] LM<sym::Optimize> [iter    9] lambda: 5.000e-08, error prev/linear/new: 923.881/0.000/913.075, rel reduction: 0.01170
# [2024-04-27 22:46:16.388] [info] LM<sym::Optimize> [iter   10] lambda: 5.000e-09, error prev/linear/new: 913.075/0.000/915.053, rel reduction: -0.00217
# [2024-04-27 22:46:25.115] [info] LM<sym::Optimize> [iter   11] lambda: 2.500e-08, error prev/linear/new: 913.075/0.000/905.974, rel reduction: 0.00778
# [2024-04-27 22:46:32.884] [info] LM<sym::Optimize> [iter   12] lambda: 2.500e-09, error prev/linear/new: 905.974/0.000/922.668, rel reduction: -0.01843
# [2024-04-27 22:46:41.905] [info] LM<sym::Optimize> [iter   13] lambda: 1.250e-08, error prev/linear/new: 905.974/0.000/906.919, rel reduction: -0.00104
# [2024-04-28T03:46:43Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:46:44Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:46:44Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:46:44Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:46:44Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Text
# [2024-04-28T03:46:44Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Text
# [2024-04-28T03:46:44Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:46:44Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 result = optimizer.optimize(initial_values)
#       2 assert(result.status == symforce.opt.optimizer.Optimizer.Status.SUCCESS)
#
# File ~/miniforge3/envs/ae598-3dv/lib/python3.10/site-packages/symforce/opt/optimizer.py:349, in Optimizer.optimize(self, initial_guess, **kwargs)
#     346 cc_values = self._cc_values(initial_guess)
#     348 try:
# --> 349     stats = self._cc_optimizer.optimize(cc_values, **kwargs)
#     350 except ZeroDivisionError as ex:
#     351     raise ZeroDivisionError("ERROR: Division by zero - check your use of epsilon!") from ex
#
# File ~/miniforge3/envs/ae598-3dv/lib/python3.10/site-packages/lcmtypes/sym/_index_entry_t.py:110, in index_entry_t.decode(data)
#     107     self.type._encode_one(buf)
#     108     buf.write(index_entry_t._CACHED_STRUCT_0.pack(self.offset, self.storage_dim, self.tangent_dim))
# --> 110 @staticmethod
#     111 def decode(data):
#     112     # type: (T.Union[bytes, T.BinaryIO]) -> index_entry_t
#     113     # NOTE(eric): This function can technically accept either a BinaryIO or
#     114     # anything that supports the C++ Buffer Protocol,
#     115     # which is unspecifiable in type hints.
#     117     if hasattr(data, "read"):
#     118         # NOTE(eric): mypy isn't able to figure out the hasattr check
#     119         buf = T.cast(T.BinaryIO, data)
#
# KeyboardInterrupt:

# %% [markdown]
# Store results from optimization (note that this modifies `views` and `tracks` in place).

# %%
sfm.store_results(views, tracks, K, result, max_reprojection_err=max_reprojection_err)
# Out:
#      2 views with updated pose estimate
#    134 valid tracks with updated position estimate
#      0 already invalid tracks
#    342 newly invalid tracks

# %% [markdown]
# Show results.

# %%
sfm.show_results(views, tracks, K)
# Out:
# POSE ESTIMATES
#  [R_inA_ofB0, p_inA_ofB0] = [[    1.0000     0.0000     0.0000     0.0000]
#                              [    0.0000     1.0000     0.0000     0.0000]
#                              [    0.0000     0.0000     1.0000     0.0000]]
#  [R_inA_ofB1, p_inA_ofB1] = [[    0.9999    -0.0073    -0.0089     0.0384]
#                              [    0.0081     0.9951     0.0990    -0.0288]
#                              [    0.0082    -0.0991     0.9950     0.9986]]
#
# REPROJECTION ERRORS
#  Image  0 (  134 points) : (mean, std, max, min) = (  0.34,   0.21,   0.74,   0.01)
#  Image  1 (  134 points) : (mean, std, max, min) = (  0.33,   0.20,   0.72,   0.01)

# %% [markdown]
# Add visualization of results to the 3D viewer.

# %%
sfm.visualize_results(views, tracks, K, frames_per_second)
# Out:
# [2024-04-28T03:31:34Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:31:34Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Text
# [2024-04-28T03:31:34Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Text
# [2024-04-28T03:31:34Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default

# %% [markdown]
# Copy results. If you want to start again from here, do the following:
#
# ```python
# views, tracks = sfm.copy_results(views_1_opt, tracks_1_opt)
# ```

# %%
views_1_opt, tracks_1_opt = sfm.copy_results(views, tracks)

# %% [markdown]
# ## Add a third image

# %%
# # helps avoid re-running the 1st part of this notebook, can also be used to test individual parts of the code
# import sfm
# importlib.reload(sfm)

# views, tracks = sfm.copy_results(views_1_opt, tracks_1_opt)

# %% [markdown]
# ### Get initial guess

# %% [markdown]
# Match new images with old images, updating views and tracks.

# %%
iC = sfm.add_next_view(views, tracks, K, matching_threshold=matching_threshold)
# Out:
# ADDING VIEW 2
#
# matching image 0 with image 2 with threshold 0.9:
#   380 good matches found
#   236 tracks created
#     0 tracks in C extended with point in B
#   144 tracks in B extended with point in C
#     0 tracks merged (trivial)
#     0 tracks merged (non-trivial)
#     0 inconsistent tracks
#
# matching image 1 with image 2 with threshold 0.9:
#   331 good matches found
#        trivial merge - ( 1,  243) ( 2,  623) - ( 0,  538) ( 1,  243) ( 2,  623)
#        trivial merge - ( 1,  214) ( 2,  616) - ( 0,  498) ( 1,  214) ( 2,  616)
#        trivial merge - ( 1, 1248) ( 2, 1869) - ( 0, 2321) ( 1, 1248) ( 2, 1869)
#        trivial merge - ( 1, 1263) ( 2, 1921) - ( 0, 2367) ( 1, 1263) ( 2, 1921)
#        trivial merge - ( 1,   93) ( 2,  454) - ( 0,  200) ( 1,   93) ( 2,  454)
#        trivial merge - ( 1,  106) ( 2,  519) - ( 0,  284) ( 1,  106) ( 2,  519)
#        trivial merge - ( 1,  236) ( 2,  631) - ( 0,  531) ( 1,  236) ( 2,  631)
#        trivial merge - ( 1,  277) ( 2,  695) - ( 0,  603) ( 1,  277) ( 2,  695)
#        trivial merge - ( 1,  335) ( 2,  801) - ( 0,  753) ( 1,  335) ( 2,  801)
#        trivial merge - ( 1, 1082) ( 2, 1706) - ( 0, 2046) ( 1, 1082) ( 2, 1706)
#        trivial merge - ( 1,  370) ( 2,  884) - ( 0,  856) ( 1,  370) ( 2,  884)
#        trivial merge - ( 1,  286) ( 2,  686) - ( 0,  609) ( 1,  286) ( 2,  686)
#        trivial merge - ( 1, 1330) ( 2, 2005) - ( 0, 2494) ( 1, 1330) ( 2, 2005)
#        trivial merge - ( 1,  554) ( 2, 1228) - ( 0, 1232) ( 1,  554) ( 2, 1228)
#        trivial merge - ( 1,  247) ( 2,  679) - ( 0,  572) ( 1,  247) ( 2,  679)
#        trivial merge - ( 1,  337) ( 2,  761) - ( 0,  206) ( 1,  337) ( 2,  761)
#        trivial merge - ( 1, 1110) ( 2, 1731) - ( 0, 2083) ( 1, 1110) ( 2, 1731)
#        FOUND INCONSISTENT - ( 0,  474) ( 1,  208) ( 2,  885) ( 2,  539)
#        trivial merge - ( 1,   94) ( 2,  455) - ( 0,  201) ( 1,   94) ( 2,  455)
#        trivial merge - ( 1,  989) ( 2, 1934) - ( 0, 1803) ( 1,  989) ( 2, 1934)
#        trivial merge - ( 1,  212) ( 2,  605) - ( 0,  488) ( 1,  212) ( 2,  605)
#        trivial merge - ( 1,  189) ( 2,  587) - ( 0,  632) ( 1,  189) ( 2,  587)
#        FOUND INCONSISTENT - ( 0,   34) ( 1,   10) ( 2,  523) ( 1,   96)
#        trivial merge - ( 1,  430) ( 2, 1115) - ( 0, 1065) ( 1,  430) ( 2, 1115)
#        trivial merge - ( 1, 1279) ( 2, 1924) - ( 0, 2405) ( 1, 1279) ( 2, 1924)
#        trivial merge - ( 1, 1144) ( 2, 1765) - ( 0, 2156) ( 1, 1144) ( 2, 1765)
#        trivial merge - ( 1,   65) ( 2,  456) - ( 0,  197) ( 1,   65) ( 2,  456)
#        trivial merge - ( 1, 1143) ( 2, 1764) - ( 0, 2155) ( 1, 1143) ( 2, 1764)
#        trivial merge - ( 1, 1145) ( 2, 1778) - ( 0, 2162) ( 1, 1145) ( 2, 1778)
#        FOUND INCONSISTENT - ( 0,  823) ( 1,  358) ( 2,  444) ( 2,  890)
#        FOUND INCONSISTENT - ( 0,  822) ( 1, 1195) ( 2,  864) ( 2, 1832)
#        FOUND INCONSISTENT - ( 0,  823) ( 1,  358) ( 2,  444) ( 2,  890) ( 1,   89)
#        FOUND INCONSISTENT - ( 0,  894) ( 1,  381) ( 2,  646) ( 1,  107)
#        trivial merge - ( 1,  276) ( 2,  694) - ( 0,  602) ( 1,  276) ( 2,  694)
#        trivial merge - ( 1,  251) ( 2,  676) - ( 0,  577) ( 1,  251) ( 2,  676)
#        trivial merge - ( 1, 1174) ( 2, 1800) - ( 0, 2203) ( 1, 1174) ( 2, 1800)
#        trivial merge - ( 1, 1146) ( 2, 1779) - ( 0, 2163) ( 1, 1146) ( 2, 1779)
#        FOUND INCONSISTENT - ( 0,  570) ( 1,  222) ( 2,   13) ( 2,  607)
#        trivial merge - ( 1, 1275) ( 2, 1913) - ( 0, 2385) ( 1, 1275) ( 2, 1913)
#        trivial merge - ( 1,   37) ( 2,  416) - ( 0,  129) ( 1,   37) ( 2,  416)
#        trivial merge - ( 1, 1115) ( 2, 1740) - ( 0, 2093) ( 1, 1115) ( 2, 1740)
#        trivial merge - ( 1,  153) ( 2,  549) - ( 0,  345) ( 1,  153) ( 2,  549)
#        trivial merge - ( 1,  682) ( 2, 1362) - ( 0, 1457) ( 1,  682) ( 2, 1362)
#        trivial merge - ( 1, 1141) ( 2, 1770) - ( 0, 2149) ( 1, 1141) ( 2, 1770)
#        trivial merge - ( 1,  257) ( 2,  671) - ( 0,  576) ( 1,  257) ( 2,  671)
#        trivial merge - ( 1,  960) ( 2, 1643) - ( 0, 1862) ( 1,  960) ( 2, 1643)
#        FOUND INCONSISTENT - ( 0, 1490) ( 1,  694) ( 2, 1382) ( 2, 1383)
#        trivial merge - ( 1,  200) ( 2,  598) - ( 0,  451) ( 1,  200) ( 2,  598)
#        trivial merge - ( 1, 1249) ( 2, 1874) - ( 0, 2331) ( 1, 1249) ( 2, 1874)
#        trivial merge - ( 1,   48) ( 2,  419) - ( 0,  141) ( 1,   48) ( 2,  419)
#        trivial merge - ( 1,  650) ( 2, 1323) - ( 0, 1407) ( 1,  650) ( 2, 1323)
#        trivial merge - ( 1,  611) ( 2, 1321) - ( 0, 1344) ( 1,  611) ( 2, 1321)
#        trivial merge - ( 1,  802) ( 2, 1481) - ( 0, 1633) ( 1,  802) ( 2, 1481)
#        trivial merge - ( 1,  456) ( 2, 1099) - ( 0, 1081) ( 1,  456) ( 2, 1099)
#        trivial merge - ( 1,  296) ( 2,  707) - ( 0,  640) ( 1,  296) ( 2,  707)
#        trivial merge - ( 1,  580) ( 2, 1261) - ( 0, 1270) ( 1,  580) ( 2, 1261)
#        trivial merge - ( 1,  293) ( 2,  730) - ( 0,  649) ( 1,  293) ( 2,  730)
#        trivial merge - ( 1,  382) ( 2, 1910) - ( 0,  889) ( 1,  382) ( 2, 1910)
#        trivial merge - ( 1, 1101) ( 2, 1721) - ( 0, 2073) ( 1, 1101) ( 2, 1721)
#        trivial merge - ( 1,  101) ( 2,  506) - ( 0,  271) ( 1,  101) ( 2,  506)
#        non-trivial merge - matches ( 1,  710) ( 2,   36)
#                            track one ( 0, 1546) ( 1,  710)
#                            track two ( 0, 1588) ( 2,   36)
#                            => ( 0, 1588) ( 2,   36) ( 0, 1546) ( 1,  710)  - False
#        FOUND INCONSISTENT - ( 0, 1588) ( 2,   36) ( 0, 1546) ( 1,  710)
#        trivial merge - ( 1,  498) ( 2, 1219) - ( 0, 1177) ( 1,  498) ( 2, 1219)
#        FOUND INCONSISTENT - ( 0, 1249) ( 1,  562) ( 2, 1236) ( 2, 1249)
#        trivial merge - ( 1,  204) ( 2,  575) - ( 0,  449) ( 1,  204) ( 2,  575)
#        FOUND INCONSISTENT - ( 0, 1563) ( 1,  845) ( 2, 1447) ( 2, 1558)
#        trivial merge - ( 1,  471) ( 2, 1181) - ( 0, 1137) ( 1,  471) ( 2, 1181)
#        FOUND INCONSISTENT - ( 0,  461) ( 1,  213) ( 2, 2055) ( 1, 1362)
#        trivial merge - ( 1,   62) ( 2,  448) - ( 0,  177) ( 1,   62) ( 2,  448)
#        trivial merge - ( 1,  657) ( 2, 1330) - ( 0, 1425) ( 1,  657) ( 2, 1330)
#        trivial merge - ( 1,  266) ( 2,  680) - ( 0,  589) ( 1,  266) ( 2,  680)
#        trivial merge - ( 1,  131) ( 2,  525) - ( 0,  320) ( 1,  131) ( 2,  525)
#        non-trivial merge - matches ( 1, 1193) ( 2, 1914)
#                            track one ( 0, 2399) ( 1, 1193)
#                            track two ( 0, 2346) ( 2, 1914)
#                            => ( 0, 2346) ( 2, 1914) ( 0, 2399) ( 1, 1193)  - False
#        FOUND INCONSISTENT - ( 0, 2346) ( 2, 1914) ( 0, 2399) ( 1, 1193)
#        trivial merge - ( 1,  623) ( 2, 1331) - ( 0, 1368) ( 1,  623) ( 2, 1331)
#        non-trivial merge - matches ( 1, 1135) ( 2, 1927)
#                            track one ( 0, 2142) ( 1, 1135)
#                            track two ( 0,  973) ( 2, 1927)
#                            => ( 0,  973) ( 2, 1927) ( 0, 2142) ( 1, 1135)  - True
#        FOUND INCONSISTENT - ( 0,  973) ( 2, 1927) ( 0, 2142) ( 1, 1135)
#        trivial merge - ( 1,  156) ( 2,  517) - ( 0,  306) ( 1,  156) ( 2,  517)
#        trivial merge - ( 1,  336) ( 2,  799) - ( 0,  752) ( 1,  336) ( 2,  799)
#        trivial merge - ( 1,  661) ( 2, 1368) - ( 0, 1454) ( 1,  661) ( 2, 1368)
#        trivial merge - ( 1,  380) ( 2,  963) - ( 0,  918) ( 1,  380) ( 2,  963)
#        trivial merge - ( 1,  155) ( 2,  528) - ( 0,  317) ( 1,  155) ( 2,  528)
#        trivial merge - ( 1,  371) ( 2,  966) - ( 0,  919) ( 1,  371) ( 2,  966)
#        trivial merge - ( 1,  143) ( 2,  548) - ( 0,  348) ( 1,  143) ( 2,  548)
#        non-trivial merge - matches ( 1, 1114) ( 2, 1443)
#                            track one ( 0, 2646) ( 1, 1114)
#                            track two ( 0, 1511) ( 2, 1443)
#                            => ( 0, 1511) ( 2, 1443) ( 0, 2646) ( 1, 1114)  - False
#        FOUND INCONSISTENT - ( 0, 1511) ( 2, 1443) ( 0, 2646) ( 1, 1114)
#        trivial merge - ( 1,  171) ( 2,  567) - ( 0,  392) ( 1,  171) ( 2,  567)
#        trivial merge - ( 1,  114) ( 2,  522) - ( 0,  297) ( 1,  114) ( 2,  522)
#        non-trivial merge - matches ( 1,  316) ( 2,  572)
#                            track one ( 0, 2348) ( 1,  316)
#                            track two ( 0,  395) ( 2,  572)
#                            => ( 0,  395) ( 2,  572) ( 0, 2348) ( 1,  316)  - False
#        FOUND INCONSISTENT - ( 0,  395) ( 2,  572) ( 0, 2348) ( 1,  316)
#        trivial merge - ( 1,  525) ( 2, 1189) - ( 0, 1192) ( 1,  525) ( 2, 1189)
#        trivial merge - ( 1,  290) ( 2,  750) - ( 0,  668) ( 1,  290) ( 2,  750)
#        trivial merge - ( 1,   44) ( 2,  429) - ( 0,  153) ( 1,   44) ( 2,  429)
#        trivial merge - ( 1,  482) ( 2, 1190) - ( 0, 1145) ( 1,  482) ( 2, 1190)
#        trivial merge - ( 1,  332) ( 2,  780) - ( 0,  741) ( 1,  332) ( 2,  780)
#        trivial merge - ( 1,  174) ( 2,  573) - ( 0,  399) ( 1,  174) ( 2,  573)
#        trivial merge - ( 1,  154) ( 2,  527) - ( 0,  316) ( 1,  154) ( 2,  527)
#        trivial merge - ( 1,  468) ( 2,  183) - ( 0, 1132) ( 1,  468) ( 2,  183)
#        trivial merge - ( 1,  585) ( 2, 1301) - ( 0, 1306) ( 1,  585) ( 2, 1301)
#        non-trivial merge - matches ( 1,    2) ( 2,  333)
#                            track one ( 0, 2211) ( 1,    2)
#                            track two ( 0,  319) ( 2,  333)
#                            => ( 0,  319) ( 2,  333) ( 0, 2211) ( 1,    2)  - False
#        FOUND INCONSISTENT - ( 0,  319) ( 2,  333) ( 0, 2211) ( 1,    2)
#        trivial merge - ( 1,  206) ( 2,  597) - ( 0,  456) ( 1,  206) ( 2,  597)
#        trivial merge - ( 1,  395) ( 2, 1035) - ( 0,  979) ( 1,  395) ( 2, 1035)
#        trivial merge - ( 1,  137) ( 2,  543) - ( 0,  332) ( 1,  137) ( 2,  543)
#        non-trivial merge - matches ( 1, 1426) ( 2, 1805)
#                            track one ( 0, 2171) ( 1, 1426)
#                            track two ( 0, 2378) ( 2, 1805)
#                            => ( 0, 2378) ( 2, 1805) ( 0, 2171) ( 1, 1426)  - False
#        FOUND INCONSISTENT - ( 0, 2378) ( 2, 1805) ( 0, 2171) ( 1, 1426)
#        trivial merge - ( 1,  184) ( 2,  547) - ( 0,  365) ( 1,  184) ( 2,  547)
#        trivial merge - ( 1,  327) ( 2,  802) - ( 0,  750) ( 1,  327) ( 2,  802)
#        trivial merge - ( 1,  239) ( 2,  633) - ( 0,  536) ( 1,  239) ( 2,  633)
#        trivial merge - ( 1,   61) ( 2,  453) - ( 0,  181) ( 1,   61) ( 2,  453)
#        FOUND INCONSISTENT - ( 0, 2800) ( 1, 1452) ( 2, 1909) ( 1,  760)
#        non-trivial merge - matches ( 1, 1218) ( 2, 1880)
#                            track one ( 0, 2276) ( 1, 1218)
#                            track two ( 0, 2725) ( 1, 1299) ( 2, 1880)
#                            => ( 0, 2725) ( 1, 1299) ( 2, 1880) ( 0, 2276) ( 1, 1218)  - False
#        FOUND INCONSISTENT - ( 0, 2725) ( 1, 1299) ( 2, 1880) ( 0, 2276) ( 1, 1218)
#        non-trivial merge - matches ( 1, 1287) ( 2, 2053)
#                            track one ( 0, 2406) ( 1, 1287)
#                            track two ( 0, 2493) ( 1, 1331) ( 2, 2053)
#                            => ( 0, 2493) ( 1, 1331) ( 2, 2053) ( 0, 2406) ( 1, 1287)  - True
#        FOUND INCONSISTENT - ( 0, 2493) ( 1, 1331) ( 2, 2053) ( 0, 2406) ( 1, 1287)
#        non-trivial merge - matches ( 1,  192) ( 2,  592)
#                            track one ( 0,  441) ( 1,  192)
#                            track two ( 0,  430) ( 2,  592)
#                            => ( 0,  430) ( 2,  592) ( 0,  441) ( 1,  192)  - False
#        FOUND INCONSISTENT - ( 0,  430) ( 2,  592) ( 0,  441) ( 1,  192)
#        trivial merge - ( 1,  104) ( 2,  483) - ( 0,  245) ( 1,  104) ( 2,  483)
#        trivial merge - ( 1,  271) ( 2,  681) - ( 0,  600) ( 1,  271) ( 2,  681)
#        FOUND INCONSISTENT - ( 0,  438) ( 1,   49) ( 2,  468) ( 2,  370)
#        trivial merge - ( 1,  238) ( 2,  610) - ( 0,  503) ( 1,  238) ( 2,  610)
#        non-trivial merge - matches ( 1,  224) ( 2,  596)
#                            track one ( 0,  459) ( 1,  224)
#                            track two ( 0, 2852) ( 2,  596)
#                            => ( 0, 2852) ( 2,  596) ( 0,  459) ( 1,  224)  - True
#        FOUND INCONSISTENT - ( 0, 2852) ( 2,  596) ( 0,  459) ( 1,  224)
#        trivial merge - ( 1,  226) ( 2,  626) - ( 0,  514) ( 1,  226) ( 2,  626)
#        non-trivial merge - matches ( 1, 1388) ( 2,  512)
#                            track one ( 0, 1404) ( 1, 1388)
#                            track two ( 0,  414) ( 1,  209) ( 2,  512)
#                            => ( 0,  414) ( 1,  209) ( 2,  512) ( 0, 1404) ( 1, 1388)  - False
#        FOUND INCONSISTENT - ( 0,  414) ( 1,  209) ( 2,  512) ( 0, 1404) ( 1, 1388)
#        trivial merge - ( 1,  695) ( 2, 1473) - ( 0, 1531) ( 1,  695) ( 2, 1473)
#        non-trivial merge - matches ( 1, 1086) ( 2, 1979)
#                            track one ( 0, 2061) ( 1, 1086)
#                            track two ( 0, 1879) ( 2, 1979)
#                            => ( 0, 1879) ( 2, 1979) ( 0, 2061) ( 1, 1086)  - True
#        FOUND INCONSISTENT - ( 0, 1879) ( 2, 1979) ( 0, 2061) ( 1, 1086)
#        trivial merge - ( 1,  196) ( 2,  584) - ( 0,  431) ( 1,  196) ( 2,  584)
#        trivial merge - ( 1,  895) ( 2, 1543) - ( 0, 1707) ( 1,  895) ( 2, 1543)
#        FOUND INCONSISTENT - ( 0, 1650) ( 1,  997) ( 2,  960) ( 2, 1152)
#        trivial merge - ( 1,   75) ( 2,  460) - ( 0,  204) ( 1,   75) ( 2,  460)
#        FOUND INCONSISTENT - ( 0,  849) ( 1,  356) ( 2,  897) ( 2,  172)
#        non-trivial merge - matches ( 1,  804) ( 2, 1461)
#                            track one ( 0, 2794) ( 1,  804)
#                            track two ( 0, 2364) ( 1,  865) ( 2, 1461)
#                            => ( 0, 2364) ( 1,  865) ( 2, 1461) ( 0, 2794) ( 1,  804)  - False
#        FOUND INCONSISTENT - ( 0, 2364) ( 1,  865) ( 2, 1461) ( 0, 2794) ( 1,  804)
#        trivial merge - ( 1,  292) ( 2,  753) - ( 0,  675) ( 1,  292) ( 2,  753)
#        non-trivial merge - matches ( 1,   78) ( 2, 1873)
#                            track one ( 0,  236) ( 1,   78)
#                            track two ( 0, 2251) ( 2, 1873)
#                            => ( 0, 2251) ( 2, 1873) ( 0,  236) ( 1,   78)  - False
#        FOUND INCONSISTENT - ( 0, 2251) ( 2, 1873) ( 0,  236) ( 1,   78)
#        FOUND INCONSISTENT - ( 0, 1464) ( 1,  848) ( 2, 1626) ( 2, 1510)
#        trivial merge - ( 1, 1184) ( 2, 1798) - ( 0, 2180) ( 1, 1184) ( 2, 1798)
#        trivial merge - ( 1,  402) ( 2,  981) - ( 0,  966) ( 1,  402) ( 2,  981)
#        non-trivial merge - matches ( 1, 1220) ( 2,  636)
#                            track one ( 0,  699) ( 1, 1220)
#                            track two ( 0, 1649) ( 2,  636)
#                            => ( 0, 1649) ( 2,  636) ( 0,  699) ( 1, 1220)  - False
#        FOUND INCONSISTENT - ( 0, 1649) ( 2,  636) ( 0,  699) ( 1, 1220)
#        FOUND INCONSISTENT - ( 0, 1650) ( 1,  997) ( 2,  960) ( 2, 1152) ( 1, 1116)
#        trivial merge - ( 1,   34) ( 2,  410) - ( 0,  122) ( 1,   34) ( 2,  410)
#        trivial merge - ( 1,   28) ( 2,  404) - ( 0,  100) ( 1,   28) ( 2,  404)
#        non-trivial merge - matches ( 1,  132) ( 2,  500)
#                            track one ( 0,  321) ( 1,  132)
#                            track two ( 0,  268) ( 2,  500)
#                            => ( 0,  268) ( 2,  500) ( 0,  321) ( 1,  132)  - True
#        FOUND INCONSISTENT - ( 0,  268) ( 2,  500) ( 0,  321) ( 1,  132)
#        trivial merge - ( 1,  146) ( 2, 1357) - ( 0,  367) ( 1,  146) ( 2, 1357)
#        trivial merge - ( 1,  364) ( 2,  337) - ( 0, 1481) ( 1,  364) ( 2,  337)
#        trivial merge - ( 1,   97) ( 2,  476) - ( 0,  250) ( 1,   97) ( 2,  476)
#        trivial merge - ( 1,  696) ( 2,  202) - ( 0, 1532) ( 1,  696) ( 2,  202)
#   136 tracks created
#    35 tracks in C extended with point in B
#    41 tracks in B extended with point in C
#   102 tracks merged (trivial)
#   102 tracks merged (non-trivial)
#    34 inconsistent tracks

# %% [markdown]
# Get data for resectioning. Look for tracks that...
# * are valid
# * have a match with `view_id` that is the same as the new view
# * have `p_inA` that is not `None`
#
# Also get data for triangulation. Look for tracks that...
# * are valid
# * have a match with `view_id` that is the same as the new view
# * have `p_inA` that is `None`

# %%
tracks_to_resection = []
tracks_to_triangulate = []
for track in tracks:
    if not track['valid']:
        continue
    
    match = sfm.get_match_with_view_id(track['matches'], iC)
    if match is None:
        continue

    if track['p_inA'] is None:
        tracks_to_triangulate.append(track)
    else:
        tracks_to_resection.append(track)

print(f'{len(tracks_to_resection)} tracks to resection')
print(f'{len(tracks_to_triangulate)} tracks to triangulate')
# Out:
# 68 tracks to resection
# 359 tracks to triangulate

# %% [markdown]
# #### Resection
#
# The output of this process is an estimate of the pose $R^C_A, p^C_A$.

# %%
p_inA = []
c = []
for track in tracks_to_resection:
    assert(track['p_inA'] is not None)
    p_inA.append(track['p_inA'])
    match = sfm.get_match_with_view_id(track['matches'], iC)
    c.append(sfm.get_pt2d_from_match(views, match))
p_inA = np.array(p_inA)
c = np.array(c)

print(f'len(p_inA) = {len(p_inA)}, len(c) = {len(c)}')
# Out:
# len(p_inA) = 68, len(c) = 68

# %% [markdown]
# Visualize the image coordinates of points on which PnP will be based.

# %%
# Create figure
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

# Show image
ax.imshow(views[iC]['img'], cmap='gray')

# Show matches corresponding to points that have already been triangulated
ax.plot(c[:, 0], c[:, 1], 'r.', markersize=4)

# Show plot    
plt.show()

# %% [markdown]
# Solve a PnP problem to estimate relative pose.

# %%
R_inC_ofA, p_inC_ofA, num_inliers, mask = sfm.resection(
    p_inA,
    c,
    K,
    rng,
    threshold=1.5,
    num_iters=8000,
)
print(f'found {num_inliers} inliers out of {len(mask)}')
# Out:
# [2024-04-28T03:31:36Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:31:37Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:31:37Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:31:37Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Text
# [2024-04-28T03:31:37Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Text
# [2024-04-28T03:31:37Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# found 1 inliers out of 68

# %% [markdown]
# Store results.

# %%
views[iC]['R_inB_ofA'] = R_inC_ofA
views[iC]['p_inB_ofA'] = p_inC_ofA

# %% [markdown]
# #### Triangulate

# %% [markdown]
# Apply function to triangulate all new tracks. Store results.

# %%
for track in tracks_to_triangulate:
    p_inA = sfm.triangulate(track, views, K)
    track['p_inA'] = p_inA

# %% [markdown]
# #### Show results

# %%
sfm.show_results(views, tracks, K)
# Out:
# POSE ESTIMATES
#  [R_inA_ofB0, p_inA_ofB0] = [[    1.0000     0.0000     0.0000     0.0000]
#                              [    0.0000     1.0000     0.0000     0.0000]
#                              [    0.0000     0.0000     1.0000     0.0000]]
#  [R_inA_ofB1, p_inA_ofB1] = [[    0.9999    -0.0073    -0.0089     0.0384]
#                              [    0.0081     0.9951     0.0990    -0.0288]
#                              [    0.0082    -0.0991     0.9950     0.9986]]
#  [R_inA_ofB2, p_inA_ofB2] = [[    0.9952     0.0328    -0.0925    -0.5448]
#                              [   -0.0180     0.9875     0.1566    -0.3264]
#                              [    0.0964    -0.1542     0.9833     2.8163]]
# REPROJECTION ERRORS
#  Image  0 (  345 points) : (mean, std, max, min) = (639.14, 5913.97, 103916.73,   0.01)
#  Image  1 (  287 points) : (mean, std, max, min) = (274.48, 955.99, 11261.14,   0.01)
#  Image  2 (  427 points) : (mean, std, max, min) = (812.84, 6021.76, 97516.32,   0.02)

# %% [markdown]
# Copy results. If you want to start again from here, do the following:
#
# ```python
# views, tracks = sfm.copy_results(views_2_ini, tracks_2_ini)
# ```

# %%
views_2_ini, tracks_2_ini = sfm.copy_results(views, tracks)

# %% [markdown]
# ### Optimize

# %% [markdown]
# Create initial values, factors, and optimized keys.

# %%
optimizer, initial_values = sfm.get_optimizer(views, tracks, K)
# Out:
# Iterate over 9 views:
#  T_inB0_ofA has an initial value
#  T_inB1_ofA has an initial value and is an optimized key
#  T_inB2_ofA has an initial value and is an optimized key
# T_inB1_ofA has an sf_scale_residual factor
# Iterate over 831 tracks:
#  track 0:
#   track_0_p_inA has an initial value and is an optimized key
#   track_0_b_0 has an initial value and an sf_projection_residual factor
#   track_0_b_1 has an initial value and an sf_projection_residual factor
#
#  ...
#
#  track 830:
#   track_830_p_inA has an initial value and is an optimized key
#   track_830_b_1 has an initial value and an sf_projection_residual factor
#   track_830_b_2 has an initial value and an sf_projection_residual factor

# %% [markdown]
# Create and run optimizer.

# %%
result = optimizer.optimize(initial_values)
assert(result.status == symforce.opt.optimizer.Optimizer.Status.SUCCESS)
# Out:
# [2024-04-28T03:31:50Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:31:51Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-27 22:31:51.646] [info] LM<sym::Optimize> [iter    0] lambda: 1.000e+00, error prev/linear/new: 1570.163/0.000/1565.415, rel reduction: 0.00302
# [2024-04-27 22:31:52.014] [info] LM<sym::Optimize> [iter    1] lambda: 1.000e-01, error prev/linear/new: 1565.415/0.000/1546.792, rel reduction: 0.01190
# [2024-04-27 22:31:52.346] [info] LM<sym::Optimize> [iter    2] lambda: 1.000e-02, error prev/linear/new: 1546.792/0.000/1533.889, rel reduction: 0.00834
# [2024-04-27 22:31:52.698] [info] LM<sym::Optimize> [iter    3] lambda: 1.000e-03, error prev/linear/new: 1533.889/0.000/1528.945, rel reduction: 0.00322
# [2024-04-27 22:31:53.033] [info] LM<sym::Optimize> [iter    4] lambda: 1.000e-04, error prev/linear/new: 1528.945/0.000/1525.941, rel reduction: 0.00197
# [2024-04-27 22:31:53.369] [info] LM<sym::Optimize> [iter    5] lambda: 1.000e-05, error prev/linear/new: 1525.941/0.000/1522.752, rel reduction: 0.00209
# [2024-04-27 22:31:53.667] [info] LM<sym::Optimize> [iter    6] lambda: 1.000e-06, error prev/linear/new: 1522.752/0.000/1520.230, rel reduction: 0.00166
# [2024-04-27 22:31:54.044] [info] LM<sym::Optimize> [iter    7] lambda: 1.000e-07, error prev/linear/new: 1520.230/0.000/1516.605, rel reduction: 0.00238
# [2024-04-28T03:31:54Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-27 22:31:54.448] [info] LM<sym::Optimize> [iter    8] lambda: 1.000e-08, error prev/linear/new: 1516.605/0.000/1514.262, rel reduction: 0.00154
# [2024-04-27 22:31:54.822] [info] LM<sym::Optimize> [iter    9] lambda: 1.000e-09, error prev/linear/new: 1514.262/0.000/1512.131, rel reduction: 0.00141
# [2024-04-27 22:31:55.141] [info] LM<sym::Optimize> [iter   10] lambda: 1.000e-10, error prev/linear/new: 1512.131/0.000/1507.011, rel reduction: 0.00339
# [2024-04-28T03:31:55Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:31:55Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:31:55Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:31:55Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Text
# [2024-04-28T03:31:55Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Text
# [2024-04-28T03:31:55Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-27 22:31:55.597] [info] LM<sym::Optimize> [iter   11] lambda: 1.000e-11, error prev/linear/new: 1507.011/0.000/1505.151, rel reduction: 0.00123
# [2024-04-27 22:31:55.939] [info] LM<sym::Optimize> [iter   12] lambda: 1.000e-12, error prev/linear/new: 1505.151/0.000/1503.168, rel reduction: 0.00132
# [2024-04-28T03:31:56Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-27 22:31:56.321] [info] LM<sym::Optimize> [iter   13] lambda: 1.000e-13, error prev/linear/new: 1503.168/0.000/1501.356, rel reduction: 0.00121
# [2024-04-27 22:31:56.644] [info] LM<sym::Optimize> [iter   14] lambda: 1.000e-14, error prev/linear/new: 1501.356/0.000/1500.341, rel reduction: 0.00068
# [2024-04-27 22:31:56.644] [warning] LM<sym::Optimize> Zero on diagonal at indices: [1321, 1322]
# [2024-04-27 22:31:57.049] [info] LM<sym::Optimize> [iter   15] lambda: 1.000e-15, error prev/linear/new: 1500.341/0.000/1503.317, rel reduction: -0.00198
# [2024-04-27 22:31:57.467] [info] LM<sym::Optimize> [iter   16] lambda: 5.000e-15, error prev/linear/new: 1500.341/0.000/1503.305, rel reduction: -0.00198
# [2024-04-27 22:31:57.875] [info] LM<sym::Optimize> [iter   17] lambda: 2.500e-14, error prev/linear/new: 1500.341/0.000/1502.201, rel reduction: -0.00124
# [2024-04-27 22:31:58.226] [info] LM<sym::Optimize> [iter   18] lambda: 1.250e-13, error prev/linear/new: 1500.341/0.000/1499.874, rel reduction: 0.00031
# [2024-04-27 22:31:58.574] [info] LM<sym::Optimize> [iter   19] lambda: 1.250e-14, error prev/linear/new: 1499.874/0.000/1503.029, rel reduction: -0.00210
# [2024-04-27 22:31:58.975] [info] LM<sym::Optimize> [iter   20] lambda: 6.250e-14, error prev/linear/new: 1499.874/0.000/1499.527, rel reduction: 0.00023
# [2024-04-27 22:31:59.369] [info] LM<sym::Optimize> [iter   21] lambda: 6.250e-15, error prev/linear/new: 1499.527/0.000/1502.842, rel reduction: -0.00221
# [2024-04-27 22:31:59.778] [info] LM<sym::Optimize> [iter   22] lambda: 3.125e-14, error prev/linear/new: 1499.527/0.000/1502.826, rel reduction: -0.00220
# [2024-04-27 22:32:00.184] [info] LM<sym::Optimize> [iter   23] lambda: 1.562e-13, error prev/linear/new: 1499.527/0.000/1502.823, rel reduction: -0.00220
# [2024-04-27 22:32:00.862] [info] LM<sym::Optimize> [iter   24] lambda: 7.813e-13, error prev/linear/new: 1499.527/0.000/1499.352, rel reduction: 0.00012
# [2024-04-27 22:32:01.457] [info] LM<sym::Optimize> [iter   25] lambda: 7.812e-14, error prev/linear/new: 1499.352/0.000/1502.787, rel reduction: -0.00229
# [2024-04-27 22:32:01.881] [info] LM<sym::Optimize> [iter   26] lambda: 3.906e-13, error prev/linear/new: 1499.352/0.000/1502.782, rel reduction: -0.00229
# [2024-04-27 22:32:02.258] [info] LM<sym::Optimize> [iter   27] lambda: 1.953e-12, error prev/linear/new: 1499.352/0.000/1502.781, rel reduction: -0.00229
# [2024-04-27 22:32:02.586] [info] LM<sym::Optimize> [iter   28] lambda: 9.766e-12, error prev/linear/new: 1499.352/0.000/1499.295, rel reduction: 0.00004

# %% [markdown]
# Store results from optimization (note that this modifies `views` and `tracks` in place).

# %%
sfm.store_results(views, tracks, K, result, max_reprojection_err=max_reprojection_err)
# Out:
#      3 views with updated pose estimate
#     69 valid tracks with updated position estimate
#    350 already invalid tracks
#    412 newly invalid tracks

# %% [markdown]
# Show results.

# %%
sfm.show_results(views, tracks, K)
# Out:
# POSE ESTIMATES
#  [R_inA_ofB0, p_inA_ofB0] = [[    1.0000     0.0000     0.0000     0.0000]
#                              [    0.0000     1.0000     0.0000     0.0000]
#                              [    0.0000     0.0000     1.0000     0.0000]]
#  [R_inA_ofB1, p_inA_ofB1] = [[    0.9999    -0.0075    -0.0089     0.0380]
#                              [    0.0084     0.9950     0.0992    -0.0281]
#                              [    0.0081    -0.0993     0.9950     0.9984]]
#  [R_inA_ofB2, p_inA_ofB2] = [[    0.9945     0.0304    -0.1000    -0.3590]
#                              [   -0.0149     0.9882     0.1522    -0.1569]
#                              [    0.1034    -0.1499     0.9833     2.4784]]
#
# REPROJECTION ERRORS
#  Image  0 (   56 points) : (mean, std, max, min) = (  0.31,   0.21,   0.73,   0.01)
#  Image  1 (   65 points) : (mean, std, max, min) = (  0.32,   0.21,   0.71,   0.00)
#  Image  2 (   17 points) : (mean, std, max, min) = (  0.40,   0.21,   0.66,   0.06)

# %% [markdown]
# Add visualization of results to the 3D viewer.

# %%
# fig, ax = plt.subplots(1, 1)
# ax.hist(initial_errors, alpha=0.5, label='before optimization')
# ax.hist(final_errors, alpha=0.5, label='after optimization')
# ax.legend()
# ax.set_xlabel('Error [pixels]')
# ax.set_ylabel('Pixel Count')
# plt.show()
views[0]
# Out:
# {'frame_id': 0,
#  'img': array([[ 66,  58,  53, ..., 218, 218, 218],
#         [ 75,  67,  57, ..., 218, 218, 218],
#         [ 56,  67,  74, ..., 218, 218, 218],
#         ...,
#         [ 15,  14,  12, ...,  65,  69,  64],
#         [ 12,  12,  11, ...,  74,  74,  69],
#         [  6,   6,   7, ...,  71,  64,  63]], dtype=uint8),
#  'R_inB_ofA': array([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]]),
#  'p_inB_ofA': array([0., 0., 0.]),
#  'pts': [{'pt2d': array([   2.37935376, 1023.84893799]),
#    'track': {'p_inA': array([ 1.7362835 , -0.36141619, -5.27214819]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 0},
#      {'view_id': 2, 'feature_id': 362}]}},
#   {'pt2d': array([   2.77779531, 1638.22949219]), 'track': None},
#   {'pt2d': array([   2.77779531, 1638.22949219]), 'track': None},
#   {'pt2d': array([   3.68949676, 1641.80981445]), 'track': None},
#   {'pt2d': array([  4.10964108, 334.62106323]), 'track': None},
#   {'pt2d': array([  4.54740953, 229.87742615]),
#    'track': {'p_inA': array([-37.12609068,  38.37832091, -12.75219823]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 5},
#      {'view_id': 1, 'feature_id': 1111}]}},
#   {'pt2d': array([   4.73007822, 1020.84796143]), 'track': None},
#   {'pt2d': array([   5.05618238, 1034.19360352]), 'track': None},
#   {'pt2d': array([   5.60430622, 1631.2265625 ]), 'track': None},
#   {'pt2d': array([   5.60430622, 1631.2265625 ]), 'track': None},
#   {'pt2d': array([   6.09069443, 1155.12658691]), 'track': None},
#   {'pt2d': array([   7.75768852, 1749.4296875 ]),
#    'track': {'p_inA': array([ 12.98597664, -19.43441817, -68.99241261]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 11},
#      {'view_id': 2, 'feature_id': 392}]}},
#   {'pt2d': array([   8.26701546, 1015.38562012]), 'track': None},
#   {'pt2d': array([  9.57641602, 194.03393555]), 'track': None},
#   {'pt2d': array([  9.57641602, 194.03393555]), 'track': None},
#   {'pt2d': array([   9.60715866, 1040.09570312]),
#    'track': {'p_inA': array([-22.63067382,   2.86829319,  71.24766402]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 15},
#      {'view_id': 1, 'feature_id': 12}]}},
#   {'pt2d': array([  9.90847397, 469.2850647 ]), 'track': None},
#   {'pt2d': array([ 10.18466949, 487.14648438]), 'track': None},
#   {'pt2d': array([  10.66691685, 1020.24468994]), 'track': None},
#   {'pt2d': array([ 11.2321043 , 487.06359863]), 'track': None},
#   {'pt2d': array([  11.74441814, 1293.59057617]), 'track': None},
#   {'pt2d': array([  12.50089359, 1197.32775879]), 'track': None},
#   {'pt2d': array([  12.65308475, 1700.21630859]), 'track': None},
#   {'pt2d': array([ 13.57963848, 591.99243164]), 'track': None},
#   {'pt2d': array([  13.58370781, 1209.5892334 ]), 'track': None},
#   {'pt2d': array([  13.77304459, 1003.12573242]), 'track': None},
#   {'pt2d': array([ 13.96538353, 411.82666016]), 'track': None},
#   {'pt2d': array([  14.17719269, 1647.92651367]), 'track': None},
#   {'pt2d': array([ 14.34657764, 346.40359497]), 'track': None},
#   {'pt2d': array([ 14.41230202, 294.80111694]), 'track': None},
#   {'pt2d': array([  14.80646706, 1130.59802246]), 'track': None},
#   {'pt2d': array([ 15.06933022, 962.7376709 ]),
#    'track': {'p_inA': array([1759.51191501, 9817.71930983, 2580.80773688]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 31},
#      {'view_id': 2, 'feature_id': 73}]}},
#   {'pt2d': array([ 15.09231377, 834.82659912]),
#    'track': {'p_inA': array([-253.51834035,   10.8577996 ,  -32.33854457]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 32},
#      {'view_id': 1, 'feature_id': 27}]}},
#   {'pt2d': array([ 15.28791332, 360.05264282]), 'track': None},
#   {'pt2d': array([ 16.02887154, 640.30718994]),
#    'track': {'p_inA': array([229.56923361,  57.20896879,  -1.54412445]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 34},
#      {'view_id': 1, 'feature_id': 10},
#      {'view_id': 2, 'feature_id': 523},
#      {'view_id': 1, 'feature_id': 96}]}},
#   {'pt2d': array([  16.03838539, 1571.72485352]), 'track': None},
#   {'pt2d': array([  17.15968513, 1086.39807129]), 'track': None},
#   {'pt2d': array([ 17.8005867 , 404.18023682]), 'track': None},
#   {'pt2d': array([  17.81661415, 1401.47106934]),
#    'track': {'p_inA': array([  8.8417802 , -34.48211612, -53.52730878]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 38},
#      {'view_id': 2, 'feature_id': 1720}]}},
#   {'pt2d': array([ 17.91407585, 800.07720947]),
#    'track': {'p_inA': array([-25.56042215,  -8.80295709,  81.90832291]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 39},
#      {'view_id': 1, 'feature_id': 14},
#      {'view_id': 2, 'feature_id': 106}]}},
#   {'pt2d': array([  17.93216324, 1376.35009766]), 'track': None},
#   {'pt2d': array([ 18.30956078, 484.98916626]),
#    'track': {'p_inA': array([ 10.63236923,  10.36206864, -32.96919018]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 41},
#      {'view_id': 2, 'feature_id': 380}]}},
#   {'pt2d': array([  18.48271179, 1593.35192871]), 'track': None},
#   {'pt2d': array([  18.52037811, 1370.08886719]),
#    'track': {'p_inA': array([ 0.19180152, -0.05627177, -0.38411048]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 43},
#      {'view_id': 1, 'feature_id': 414}]}},
#   {'pt2d': array([  18.651474  , 1662.42919922]), 'track': None},
#   {'pt2d': array([  18.66858292, 1588.34643555]), 'track': None},
#   {'pt2d': array([  18.66858292, 1588.34643555]), 'track': None},
#   {'pt2d': array([ 19.29845047, 386.48236084]), 'track': None},
#   {'pt2d': array([ 19.70914841, 508.6237793 ]), 'track': None},
#   {'pt2d': array([ 19.79693222, 392.8989563 ]), 'track': None},
#   {'pt2d': array([  19.88328934, 1671.51501465]), 'track': None},
#   {'pt2d': array([  19.94513512, 1151.90783691]), 'track': None},
#   {'pt2d': array([  19.94513512, 1151.90783691]), 'track': None},
#   {'pt2d': array([  19.94513512, 1151.90783691]), 'track': None},
#   {'pt2d': array([  20.68079948, 1636.52075195]), 'track': None},
#   {'pt2d': array([  20.90857506, 1125.98962402]), 'track': None},
#   {'pt2d': array([  20.95081139, 1573.73413086]), 'track': None},
#   {'pt2d': array([ 21.34392929, 467.12295532]),
#    'track': {'p_inA': array([ -6.37547248, -13.60700861, -19.27158403]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 57},
#      {'view_id': 2, 'feature_id': 243}]}},
#   {'pt2d': array([  21.37856865, 1342.36462402]),
#    'track': {'p_inA': array([ 0.0165274 , -0.09561335, -0.09301575]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 58},
#      {'view_id': 1, 'feature_id': 1069}]}},
#   {'pt2d': array([  21.37856865, 1342.36462402]),
#    'track': {'p_inA': array([ 0.01652529, -0.09560114, -0.0929081 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 59},
#      {'view_id': 1, 'feature_id': 1068}]}},
#   {'pt2d': array([  21.40571976, 1057.68017578]), 'track': None},
#   {'pt2d': array([  21.85193443, 1651.05126953]),
#    'track': {'p_inA': array([-2172.10688775,  2890.17922148,  7003.87042331]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 61},
#      {'view_id': 1, 'feature_id': 928},
#      {'view_id': 2, 'feature_id': 52}]}},
#   {'pt2d': array([  22.26298332, 1563.30969238]), 'track': None},
#   {'pt2d': array([  22.46553993, 1291.02758789]),
#    'track': {'p_inA': array([ 37.25176212, -26.94875975, -45.89466434]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 63},
#      {'view_id': 1, 'feature_id': 1237}]}},
#   {'pt2d': array([  22.46553993, 1291.02758789]), 'track': None},
#   {'pt2d': array([ 22.55157661, 516.06542969]),
#    'track': {'p_inA': array([-34.63877994, -31.28001974, 111.992891  ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 65},
#      {'view_id': 1, 'feature_id': 9}]}},
#   {'pt2d': array([  23.15877724, 1683.73925781]), 'track': None},
#   {'pt2d': array([  23.16794205, 1243.17749023]),
#    'track': {'p_inA': array([ 0.03625813, -0.27358083,  0.45408843]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 67},
#      {'view_id': 2, 'feature_id': 394},
#      {'view_id': 1, 'feature_id': 437}]}},
#   {'pt2d': array([  23.16794205, 1243.17749023]), 'track': None},
#   {'pt2d': array([  23.16794205, 1243.17749023]), 'track': None},
#   {'pt2d': array([  23.54695129, 1082.8927002 ]), 'track': None},
#   {'pt2d': array([  23.54695129, 1082.8927002 ]), 'track': None},
#   {'pt2d': array([ 23.69814873, 378.02075195]), 'track': None},
#   {'pt2d': array([  23.9538517 , 1005.87133789]), 'track': None},
#   {'pt2d': array([  24.31561279, 1374.01037598]), 'track': None},
#   {'pt2d': array([ 25.2762661, 370.7850647]), 'track': None},
#   {'pt2d': array([  25.38294792, 1049.41137695]), 'track': None},
#   {'pt2d': array([ 25.412117 , 328.2371521]),
#    'track': {'p_inA': array([ 23.73585439,  30.46169247, -76.71108038]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 77},
#      {'view_id': 1, 'feature_id': 17}]}},
#   {'pt2d': array([  25.65442467, 1475.30712891]),
#    'track': {'p_inA': array([-1045.83086184,  1555.17473618,  4919.32344178]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 78},
#      {'view_id': 1, 'feature_id': 365}]}},
#   {'pt2d': array([  25.72391319, 1053.07507324]), 'track': None},
#   {'pt2d': array([  25.93394089, 1406.0423584 ]), 'track': None},
#   {'pt2d': array([ 26.18004417, 838.19671631]),
#    'track': {'p_inA': array([-45.73196052, -12.45860595, 148.82812019]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 81},
#      {'view_id': 1, 'feature_id': 43}]}},
#   {'pt2d': array([  26.23176765, 1197.20898438]), 'track': None},
#   {'pt2d': array([  26.46907234, 1006.85174561]),
#    'track': {'p_inA': array([12503.21431691, -4499.43930867,  1987.66479666]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 83},
#      {'view_id': 2, 'feature_id': 1363}]}},
#   {'pt2d': array([ 26.47596169, 637.27026367]), 'track': None},
#   {'pt2d': array([  26.51196861, 1605.15942383]), 'track': None},
#   {'pt2d': array([  26.51196861, 1605.15942383]), 'track': None},
#   {'pt2d': array([  26.51196861, 1605.15942383]), 'track': None},
#   {'pt2d': array([  26.6326313 , 1154.57043457]), 'track': None},
#   {'pt2d': array([  27.06200409, 1566.58374023]),
#    'track': {'p_inA': array([-305.28058809,  213.32579418, -180.32901723]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 89},
#      {'view_id': 2, 'feature_id': 1507}]}},
#   {'pt2d': array([  27.37112045, 1224.59545898]), 'track': None},
#   {'pt2d': array([  27.37112045, 1224.59545898]), 'track': None},
#   {'pt2d': array([ 27.78493309, 557.81359863]),
#    'track': {'p_inA': array([-47.03092242, -38.84258379, 153.40459321]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 92},
#      {'view_id': 1, 'feature_id': 23}]}},
#   {'pt2d': array([ 27.92212296, 816.65454102]),
#    'track': {'p_inA': array([-34.43749308, -10.80809798, 112.41917577]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 93},
#      {'view_id': 1, 'feature_id': 39}]}},
#   {'pt2d': array([  28.83521843, 1895.13354492]), 'track': None},
#   {'pt2d': array([  28.83521843, 1895.13354492]), 'track': None},
#   {'pt2d': array([  29.26989365, 1070.12304688]), 'track': None},
#   {'pt2d': array([  29.26989365, 1070.12304688]), 'track': None},
#   {'pt2d': array([  29.49337578, 1534.8638916 ]), 'track': None},
#   {'pt2d': array([  29.55672646, 1205.1036377 ]), 'track': None},
#   {'pt2d': array([ 29.87502861, 467.64230347]),
#    'track': {'p_inA': array([-103.01409771, -104.22602485,  337.77755829]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 100},
#      {'view_id': 1, 'feature_id': 28},
#      {'view_id': 2, 'feature_id': 404}]}},
#   {'pt2d': array([  29.93161011, 1261.08215332]), 'track': None},
#   {'pt2d': array([  30.50940514, 1696.14001465]), 'track': None},
#   {'pt2d': array([  30.97953415, 1342.85681152]),
#    'track': {'p_inA': array([ 0.57055934, -0.40531097, -1.9839982 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 103},
#      {'view_id': 2, 'feature_id': 595}]}},
#   {'pt2d': array([  30.97953415, 1342.85681152]),
#    'track': {'p_inA': array([ 1104.50998139,  -871.399342  , -3599.4489018 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 104},
#      {'view_id': 1, 'feature_id': 1187}]}},
#   {'pt2d': array([  31.22340202, 1371.2635498 ]), 'track': None},
#   {'pt2d': array([  31.22340202, 1371.2635498 ]),
#    'track': {'p_inA': array([143.00675591, -81.38712525, -42.86064407]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 106},
#      {'view_id': 2, 'feature_id': 1408}]}},
#   {'pt2d': array([  31.22340202, 1371.2635498 ]), 'track': None},
#   {'pt2d': array([ 32.02368164, 735.29779053]),
#    'track': {'p_inA': array([-128.93849367, -522.00756168, 4020.84480826]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 108},
#      {'view_id': 2, 'feature_id': 374}]}},
#   {'pt2d': array([  32.79315948, 1582.06469727]), 'track': None},
#   {'pt2d': array([  33.16482925, 1262.33068848]), 'track': None},
#   {'pt2d': array([ 33.25231934, 327.01791382]),
#    'track': {'p_inA': array([ -9448.2921732 , -10909.45009812,  16921.13128528]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 111},
#      {'view_id': 1, 'feature_id': 24}]}},
#   {'pt2d': array([ 33.43186188, 978.59216309]), 'track': None},
#   {'pt2d': array([ 33.45611572, 286.53771973]), 'track': None},
#   {'pt2d': array([  33.54061127, 1295.14685059]), 'track': None},
#   {'pt2d': array([ 33.70066833, 282.56292725]), 'track': None},
#   {'pt2d': array([ 33.73582458, 831.09436035]), 'track': None},
#   {'pt2d': array([ 34.31954193, 961.35577393]), 'track': None},
#   {'pt2d': array([  34.37929153, 1043.86816406]), 'track': None},
#   {'pt2d': array([  34.50424957, 1627.92810059]), 'track': None},
#   {'pt2d': array([  34.56906128, 1640.32275391]), 'track': None},
#   {'pt2d': array([  35.21993637, 1694.35559082]), 'track': None},
#   {'pt2d': array([ 35.50101852, 497.76647949]),
#    'track': {'p_inA': array([-69.47173091, -67.03777281, 230.64969893]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 122},
#      {'view_id': 1, 'feature_id': 34},
#      {'view_id': 2, 'feature_id': 410}]}},
#   {'pt2d': array([  36.15315628, 1204.43933105]),
#    'track': {'p_inA': array([-33.30115665,  15.5080411 , 110.4485159 ]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 123},
#      {'view_id': 1, 'feature_id': 82}]}},
#   {'pt2d': array([  36.15315628, 1204.43933105]),
#    'track': {'p_inA': array([  9312.00043317,  -6113.88960359, -12624.91914455]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 124},
#      {'view_id': 1, 'feature_id': 445}]}},
#   {'pt2d': array([  36.96343994, 1631.42529297]), 'track': None},
#   {'pt2d': array([  36.96343994, 1631.42529297]), 'track': None},
#   {'pt2d': array([  36.98334122, 1586.55517578]), 'track': None},
#   {'pt2d': array([  36.98334122, 1586.55517578]), 'track': None},
#   {'pt2d': array([ 37.05642319, 450.74758911]),
#    'track': {'p_inA': array([-104.68716874, -111.12416033,  348.39065728]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 129},
#      {'view_id': 1, 'feature_id': 37},
#      {'view_id': 2, 'feature_id': 416}]}},
#   {'pt2d': array([  37.47797775, 1134.8692627 ]), 'track': None},
#   {'pt2d': array([  37.7299881 , 1212.62805176]), 'track': None},
#   {'pt2d': array([  37.85599518, 1294.4005127 ]), 'track': None},
#   {'pt2d': array([  37.88393784, 1037.62915039]), 'track': None},
#   {'pt2d': array([  38.02447128, 1645.08483887]), 'track': None},
#   {'pt2d': array([  38.54014969, 1459.0559082 ]), 'track': None},
#   {'pt2d': array([  39.72196579, 1052.4675293 ]),
#    'track': {'p_inA': array([  3.89784503,  -0.55085241, -12.72220042]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 136},
#      {'view_id': 1, 'feature_id': 124}]}},
#   {'pt2d': array([  39.80570221, 1673.59875488]), 'track': None},
#   {'pt2d': array([  39.80570221, 1673.59875488]), 'track': None},
#   {'pt2d': array([  40.25656128, 1346.28662109]), 'track': None},
#   {'pt2d': array([  40.50717926, 1122.11279297]), 'track': None},
#   {'pt2d': array([ 40.5995636 , 472.60684204]),
#    'track': {'p_inA': array([-100.34806173, -102.72669191,  336.22886268]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 141},
#      {'view_id': 1, 'feature_id': 48},
#      {'view_id': 2, 'feature_id': 419}]}},
#   {'pt2d': array([ 40.5995636 , 472.60684204]),
#    'track': {'p_inA': array([ 1403.70027002,   642.99025137, -2705.99332301]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 142},
#      {'view_id': 1, 'feature_id': 1123}]}},
#   {'pt2d': array([ 41.32927322, 959.92687988]), 'track': None},
#   {'pt2d': array([  41.78016281, 1294.83776855]), 'track': None},
#   {'pt2d': array([  42.13227463, 1166.16442871]), 'track': None},
#   {'pt2d': array([  42.13227463, 1166.16442871]), 'track': None},
#   {'pt2d': array([  42.13227463, 1166.16442871]), 'track': None},
#   {'pt2d': array([  42.55030441, 1019.1932373 ]),
#    'track': {'p_inA': array([ 0.9881347 , -0.53504294, -0.10149636]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 148},
#      {'view_id': 1, 'feature_id': 1198}]}},
#   {'pt2d': array([ 42.66658783, 442.70413208]),
#    'track': {'p_inA': array([-89.27674998, -97.4386118 , 300.7045898 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 149},
#      {'view_id': 1, 'feature_id': 52}]}},
#   {'pt2d': array([  44.00718307, 1316.3692627 ]), 'track': None},
#   {'pt2d': array([  44.00718307, 1316.3692627 ]), 'track': None},
#   {'pt2d': array([  44.21678543, 1682.99047852]), 'track': None},
#   {'pt2d': array([ 44.44213486, 327.13830566]),
#    'track': {'p_inA': array([ -93.23301678, -124.029075  ,  314.79186113]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 153},
#      {'view_id': 1, 'feature_id': 44},
#      {'view_id': 2, 'feature_id': 429}]}},
#   {'pt2d': array([  45.12203979, 1320.03417969]), 'track': None},
#   {'pt2d': array([ 45.49302673, 457.88803101]), 'track': None},
#   {'pt2d': array([ 46.06545258, 959.68011475]),
#    'track': {'p_inA': array([ 0.32052984, -0.13625309, -0.99646957]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 156},
#      {'view_id': 2, 'feature_id': 735}]}},
#   {'pt2d': array([  46.35358429, 1314.19873047]), 'track': None},
#   {'pt2d': array([  46.35358429, 1314.19873047]), 'track': None},
#   {'pt2d': array([ 46.70871353, 630.27050781]), 'track': None},
#   {'pt2d': array([  46.79315567, 1013.93231201]), 'track': None},
#   {'pt2d': array([  46.79315567, 1013.93231201]), 'track': None},
#   {'pt2d': array([ 47.39384842, 893.34765625]),
#    'track': {'p_inA': array([-24.03098861,  -3.92410524,  81.56783918]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 162},
#      {'view_id': 1, 'feature_id': 77},
#      {'view_id': 2, 'feature_id': 421}]}},
#   {'pt2d': array([  47.88310623, 1883.60681152]), 'track': None},
#   {'pt2d': array([  47.88310623, 1883.60681152]),
#    'track': {'p_inA': array([ 0.08123127, -0.30765925, -0.89282702]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 164},
#      {'view_id': 2, 'feature_id': 1392},
#      {'view_id': 1, 'feature_id': 654}]}},
#   {'pt2d': array([ 47.95787048, 420.27243042]), 'track': None},
#   {'pt2d': array([  48.43126678, 1035.05175781]),
#    'track': {'p_inA': array([-0.22690718, -0.01553399,  1.69280956]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 166},
#      {'view_id': 2, 'feature_id': 1163},
#      {'view_id': 1, 'feature_id': 548}]}},
#   {'pt2d': array([  48.82735062, 1259.02502441]), 'track': None},
#   {'pt2d': array([  48.82735062, 1259.02502441]), 'track': None},
#   {'pt2d': array([  49.07301712, 1652.46350098]), 'track': None},
#   {'pt2d': array([  49.07301712, 1652.46350098]),
#    'track': {'p_inA': array([  -9.74586828, 1596.86706434, 3791.01764147]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 170},
#      {'view_id': 2, 'feature_id': 687}]}},
#   {'pt2d': array([  49.14930344, 1196.31604004]), 'track': None},
#   {'pt2d': array([  49.40080643, 1681.4395752 ]), 'track': None},
#   {'pt2d': array([  49.81566238, 1725.90710449]), 'track': None},
#   {'pt2d': array([  49.81566238, 1725.90710449]), 'track': None},
#   {'pt2d': array([ 49.90014267, 739.43157959]),
#    'track': {'p_inA': array([ 32.77943925,  10.17310702, -60.7495057 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 175},
#      {'view_id': 1, 'feature_id': 31}]}},
#   {'pt2d': array([ 50.21222305, 995.09197998]), 'track': None},
#   {'pt2d': array([ 51.22452545, 451.86621094]),
#    'track': {'p_inA': array([-85.92886795, -93.77696721, 294.5337317 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 177},
#      {'view_id': 1, 'feature_id': 62},
#      {'view_id': 2, 'feature_id': 448}]}},
#   {'pt2d': array([  52.04795074, 1030.02990723]), 'track': None},
#   {'pt2d': array([  52.23184586, 1668.55822754]), 'track': None},
#   {'pt2d': array([  52.23184586, 1668.55822754]), 'track': None},
#   {'pt2d': array([ 52.39572525, 318.51376343]),
#    'track': {'p_inA': array([  49.48990511,   63.8580422 , -126.68048143]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 181},
#      {'view_id': 1, 'feature_id': 61},
#      {'view_id': 2, 'feature_id': 453}]}},
#   {'pt2d': array([  52.57918167, 1030.76281738]),
#    'track': {'p_inA': array([  4.15848295,  -0.58452412, -14.01471402]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 182},
#      {'view_id': 1, 'feature_id': 165}]}},
#   {'pt2d': array([  52.60063171, 1252.27368164]), 'track': None},
#   {'pt2d': array([ 53.02553558, 741.84234619]),
#    'track': {'p_inA': array([-25.39078191, -12.42231748,  87.32291906]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 184},
#      {'view_id': 1, 'feature_id': 80}]}},
#   {'pt2d': array([ 53.02553558, 741.84234619]), 'track': None},
#   {'pt2d': array([ 53.23871231, 551.74127197]), 'track': None},
#   {'pt2d': array([  53.48410797, 1589.44030762]), 'track': None},
#   {'pt2d': array([  53.48410797, 1589.44030762]), 'track': None},
#   {'pt2d': array([  53.48410797, 1589.44030762]), 'track': None},
#   {'pt2d': array([  53.48410797, 1589.44030762]), 'track': None},
#   {'pt2d': array([ 53.56840897, 436.09609985]), 'track': None},
#   {'pt2d': array([  53.65909195, 1372.00073242]), 'track': None},
#   {'pt2d': array([  53.7766304 , 1564.22058105]), 'track': None},
#   {'pt2d': array([ 53.87281418, 555.58984375]),
#    'track': {'p_inA': array([-4172.59652127, -4843.29945276, 17688.72752539]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 194},
#      {'view_id': 2, 'feature_id': 710}]}},
#   {'pt2d': array([  54.06188583, 1606.26550293]), 'track': None},
#   {'pt2d': array([  54.06188583, 1606.26550293]), 'track': None},
#   {'pt2d': array([ 55.42390823, 380.75247192]),
#    'track': {'p_inA': array([-203.30130091, -253.2811    ,  701.52261389]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 197},
#      {'view_id': 1, 'feature_id': 65},
#      {'view_id': 2, 'feature_id': 456}]}},
#   {'pt2d': array([  55.42786789, 1291.49719238]),
#    'track': {'p_inA': array([-112.01217081,   56.18295702,  -44.78777008]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 198},
#      {'view_id': 2, 'feature_id': 1525}]}},
#   {'pt2d': array([  55.63913345, 1675.78051758]), 'track': None},
#   {'pt2d': array([ 55.96905899, 848.23052979]),
#    'track': {'p_inA': array([-39.91472994, -10.65155531, 138.00569497]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 200},
#      {'view_id': 1, 'feature_id': 93},
#      {'view_id': 2, 'feature_id': 454}]}},
#   {'pt2d': array([ 55.96905899, 848.23052979]),
#    'track': {'p_inA': array([-39.91472994, -10.65155531, 138.00569497]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 201},
#      {'view_id': 1, 'feature_id': 94},
#      {'view_id': 2, 'feature_id': 455}]}},
#   {'pt2d': array([  55.98500061, 1616.84448242]), 'track': None},
#   {'pt2d': array([ 56.24602127, 627.15032959]), 'track': None},
#   {'pt2d': array([ 56.35953522, 536.34448242]),
#    'track': {'p_inA': array([-41.75102641, -38.62288531, 144.64631964]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 204},
#      {'view_id': 1, 'feature_id': 75},
#      {'view_id': 2, 'feature_id': 460}]}},
#   {'pt2d': array([  56.47868729, 1427.93615723]), 'track': None},
#   {'pt2d': array([ 56.77258682, 957.95025635]),
#    'track': {'p_inA': array([ 0.97408145,  0.0525386 , -3.34297343]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 206},
#      {'view_id': 1, 'feature_id': 337},
#      {'view_id': 2, 'feature_id': 761}]}},
#   {'pt2d': array([  57.1028595, 1877.2911377]),
#    'track': {'p_inA': array([-16.75252788,  31.93549573,  58.01988712]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 207},
#      {'view_id': 1, 'feature_id': 172},
#      {'view_id': 2, 'feature_id': 198}]}},
#   {'pt2d': array([  57.1028595, 1877.2911377]),
#    'track': {'p_inA': array([-16.75255709,  31.93555126,  58.01998743]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 208},
#      {'view_id': 1, 'feature_id': 173}]}},
#   {'pt2d': array([  57.1332016 , 1244.98046875]), 'track': None},
#   {'pt2d': array([  57.1332016 , 1244.98046875]),
#    'track': {'p_inA': array([-50.52977198,  48.5802898 , -24.94012964]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 210},
#      {'view_id': 2, 'feature_id': 2045}]}},
#   {'pt2d': array([  57.67730331, 1282.8572998 ]),
#    'track': {'p_inA': array([ 162.79213816, -137.49216639, -355.2969961 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 211},
#      {'view_id': 1, 'feature_id': 1235}]}},
#   {'pt2d': array([  57.67730331, 1282.8572998 ]), 'track': None},
#   {'pt2d': array([  57.82626343, 1163.42199707]), 'track': None},
#   {'pt2d': array([  57.82626343, 1163.42199707]), 'track': None},
#   {'pt2d': array([  57.82626343, 1163.42199707]), 'track': None},
#   {'pt2d': array([ 58.25271225, 404.55886841]),
#    'track': {'p_inA': array([-229.58060749, -276.23708282,  797.0520592 ]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 216},
#      {'view_id': 1, 'feature_id': 71}]}},
#   {'pt2d': array([ 58.25271225, 404.55886841]),
#    'track': {'p_inA': array([-229.58060749, -276.23708282,  797.05205921]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 217},
#      {'view_id': 1, 'feature_id': 72}]}},
#   {'pt2d': array([ 59.01054001, 873.8270874 ]), 'track': None},
#   {'pt2d': array([ 59.07443619, 976.42724609]), 'track': None},
#   {'pt2d': array([ 59.07443619, 976.42724609]), 'track': None},
#   {'pt2d': array([  59.77492142, 1419.25219727]), 'track': None},
#   {'pt2d': array([  60.14549637, 1480.82263184]), 'track': None},
#   {'pt2d': array([  60.16228867, 1566.09692383]), 'track': None},
#   {'pt2d': array([  60.16228867, 1566.09692383]), 'track': None},
#   {'pt2d': array([ 60.69395828, 960.4597168 ]),
#    'track': {'p_inA': array([-35.24840495,  -1.02735764, 123.03836041]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 225},
#      {'view_id': 1, 'feature_id': 105},
#      {'view_id': 2, 'feature_id': 927}]}},
#   {'pt2d': array([ 60.7305069 , 969.37762451]),
#    'track': {'p_inA': array([ 4.45278669, -0.61612553, -2.59181645]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 226},
#      {'view_id': 1, 'feature_id': 472}]}},
#   {'pt2d': array([ 60.7305069 , 969.37762451]), 'track': None},
#   {'pt2d': array([ 60.7305069 , 969.37762451]), 'track': None},
#   {'pt2d': array([ 60.7305069 , 969.37762451]), 'track': None},
#   {'pt2d': array([ 60.8255806 , 421.85958862]),
#    'track': {'p_inA': array([-151.83218281, -178.56348313,  530.73765009]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 230},
#      {'view_id': 1, 'feature_id': 84}]}},
#   {'pt2d': array([ 60.83272552, 974.18743896]), 'track': None},
#   {'pt2d': array([  61.16082001, 1194.52929688]), 'track': None},
#   {'pt2d': array([ 61.29152679, 802.24499512]),
#    'track': {'p_inA': array([  6.52870867,   2.30258111, -22.27872063]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 233},
#      {'view_id': 2, 'feature_id': 464}]}},
#   {'pt2d': array([  61.36549759, 1050.61633301]), 'track': None},
#   {'pt2d': array([ 62.38939285, 456.5428772 ]),
#    'track': {'p_inA': array([-84.3984872 , -93.06402052, 295.56858189]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 235},
#      {'view_id': 1, 'feature_id': 86}]}},
#   {'pt2d': array([ 62.42387009, 610.54504395]),
#    'track': {'p_inA': array([-17.75530611, -13.75177733,  62.19858189]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 2251},
#      {'view_id': 2, 'feature_id': 1873},
#      {'view_id': 0, 'feature_id': 236},
#      {'view_id': 1, 'feature_id': 78}]}},
#   {'pt2d': array([  62.63642502, 1045.99047852]),
#    'track': {'p_inA': array([-10368.77851534, -44934.40741036, -26641.02130958]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 237},
#      {'view_id': 2, 'feature_id': 334}]}},
#   {'pt2d': array([  63.15416718, 1142.63391113]), 'track': None},
#   {'pt2d': array([  63.26733017, 1669.66589355]),
#    'track': {'p_inA': array([-2.27840091,  2.08156439, -0.19428759]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 239},
#      {'view_id': 1, 'feature_id': 748},
#      {'view_id': 2, 'feature_id': 1413}]}},
#   {'pt2d': array([  63.26733017, 1669.66589355]), 'track': None},
#   {'pt2d': array([  63.62311554, 1081.65771484]), 'track': None},
#   {'pt2d': array([  63.88579941, 1103.68249512]), 'track': None},
#   {'pt2d': array([ 63.93992233, 613.44519043]), 'track': None},
#   {'pt2d': array([ 64.5850296 , 876.89044189]),
#    'track': {'p_inA': array([-43.06486244,  -9.12891638, 151.66744735]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 244},
#      {'view_id': 1, 'feature_id': 111},
#      {'view_id': 2, 'feature_id': 68}]}},
#   {'pt2d': array([ 64.62271118, 829.66729736]),
#    'track': {'p_inA': array([-31.71832139,  -9.82192073, 111.67424565]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 245},
#      {'view_id': 1, 'feature_id': 104},
#      {'view_id': 2, 'feature_id': 483}]}},
#   {'pt2d': array([  65.29740906, 1288.80456543]), 'track': None},
#   {'pt2d': array([  65.29740906, 1288.80456543]), 'track': None},
#   {'pt2d': array([ 65.37348938, 864.05285645]),
#    'track': {'p_inA': array([-35.07692569,  -8.3403695 , 123.71382653]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 248},
#      {'view_id': 1, 'feature_id': 108}]}},
#   {'pt2d': array([ 65.37348938, 864.05285645]),
#    'track': {'p_inA': array([-35.07692569,  -8.3403695 , 123.71382653]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 249},
#      {'view_id': 1, 'feature_id': 109}]}},
#   {'pt2d': array([ 65.89670563, 654.39025879]),
#    'track': {'p_inA': array([-34.19878299, -23.54922636, 120.8163933 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 250},
#      {'view_id': 1, 'feature_id': 97},
#      {'view_id': 2, 'feature_id': 476}]}},
#   {'pt2d': array([  66.39466858, 1566.34790039]), 'track': None},
#   {'pt2d': array([  66.53870392, 1029.89526367]), 'track': None},
#   {'pt2d': array([  66.58167267, 1639.6048584 ]), 'track': None},
#   {'pt2d': array([  66.6124649 , 1091.94604492]), 'track': None},
#   {'pt2d': array([  66.6124649 , 1091.94604492]), 'track': None},
#   {'pt2d': array([  66.85076141, 1275.36987305]), 'track': None},
#   {'pt2d': array([  67.28822327, 1040.97143555]),
#    'track': {'p_inA': array([-3.47604158,  0.49589569, 12.30036225]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 257},
#      {'view_id': 1, 'feature_id': 54}]}},
#   {'pt2d': array([ 67.30784607, 623.60357666]), 'track': None},
#   {'pt2d': array([ 67.33071136, 832.24182129]), 'track': None},
#   {'pt2d': array([  67.61688995, 1025.61865234]),
#    'track': {'p_inA': array([-26.59905232,   3.00251249,  94.25289015]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 260},
#      {'view_id': 1, 'feature_id': 128},
#      {'view_id': 2, 'feature_id': 174}]}},
#   {'pt2d': array([  67.63681793, 1665.12438965]), 'track': None},
#   {'pt2d': array([  68.11775208, 1391.38232422]), 'track': None},
#   {'pt2d': array([  68.17285156, 1872.80383301]), 'track': None},
#   {'pt2d': array([  69.38613892, 1093.28405762]), 'track': None},
#   {'pt2d': array([ 69.91833496, 467.02276611]),
#    'track': {'p_inA': array([  8.59492643,   9.72317278, -29.43144927]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 265},
#      {'view_id': 2, 'feature_id': 499}]}},
#   {'pt2d': array([ 70.50467682, 972.20159912]),
#    'track': {'p_inA': array([4899.75145632,   86.47020477, 3910.44764835]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 266},
#      {'view_id': 2, 'feature_id': 446}]}},
#   {'pt2d': array([ 70.83815002, 452.6942749 ]), 'track': None},
#   {'pt2d': array([ 70.93344879, 459.00448608]),
#    'track': {'p_inA': array([-86.03481542, -99.92072846, 316.54869848]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 268},
#      {'view_id': 2, 'feature_id': 500},
#      {'view_id': 0, 'feature_id': 321},
#      {'view_id': 1, 'feature_id': 132}]}},
#   {'pt2d': array([  71.31923676, 1202.04406738]),
#    'track': {'p_inA': array([ -7.96704996,   3.29569442, -10.81758004]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 269},
#      {'view_id': 1, 'feature_id': 757},
#      {'view_id': 2, 'feature_id': 1398}]}},
#   {'pt2d': array([  71.5035553 , 1389.05175781]), 'track': None},
#   {'pt2d': array([ 71.94885254, 443.89266968]),
#    'track': {'p_inA': array([-107.87282315, -124.79644617,  386.27995091]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 271},
#      {'view_id': 1, 'feature_id': 101},
#      {'view_id': 2, 'feature_id': 506}]}},
#   {'pt2d': array([  72.78874969, 1596.51123047]), 'track': None},
#   {'pt2d': array([  72.78874969, 1596.51123047]), 'track': None},
#   {'pt2d': array([  73.20944214, 1649.3894043 ]), 'track': None},
#   {'pt2d': array([ 73.57643127, 471.30264282]),
#    'track': {'p_inA': array([ 1.04245472,  1.19628783, -2.71184029]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 275},
#      {'view_id': 2, 'feature_id': 509},
#      {'view_id': 1, 'feature_id': 92}]}},
#   {'pt2d': array([ 73.57643127, 471.30264282]), 'track': None},
#   {'pt2d': array([  73.6713028 , 1029.97595215]),
#    'track': {'p_inA': array([-948.27542209, -227.85897904, 4963.31861881]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 277},
#      {'view_id': 2, 'feature_id': 227}]}},
#   {'pt2d': array([  74.03982544, 1350.56677246]), 'track': None},
#   {'pt2d': array([ 74.17695618, 949.49938965]), 'track': None},
#   {'pt2d': array([ 74.43136597, 462.52902222]), 'track': None},
#   {'pt2d': array([  76.37062073, 1150.34362793]), 'track': None},
#   {'pt2d': array([  76.37062073, 1150.34362793]), 'track': None},
#   {'pt2d': array([ 76.7117157 , 871.13232422]), 'track': None},
#   {'pt2d': array([ 76.98603821, 426.00592041]),
#    'track': {'p_inA': array([-140.4164966 , -169.58975946,  508.08822037]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 284},
#      {'view_id': 1, 'feature_id': 106},
#      {'view_id': 2, 'feature_id': 519}]}},
#   {'pt2d': array([  77.3788681, 1050.3112793]), 'track': None},
#   {'pt2d': array([  77.6384201 , 1865.08129883]),
#    'track': {'p_inA': array([-383.21295968, -157.37539049,   -6.20003983]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 286},
#      {'view_id': 2, 'feature_id': 458}]}},
#   {'pt2d': array([  77.70162201, 1615.24719238]),
#    'track': {'p_inA': array([ 4.31892052, -6.64491886, -4.83784923]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 287},
#      {'view_id': 1, 'feature_id': 1012}]}},
#   {'pt2d': array([  78.00643158, 1099.79138184]), 'track': None},
#   {'pt2d': array([  78.55968475, 1222.16333008]),
#    'track': {'p_inA': array([ 1305.32917906,  -756.32338372, -4712.62622288]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 289},
#      {'view_id': 2, 'feature_id': 514}]}},
#   {'pt2d': array([  78.55968475, 1222.16333008]), 'track': None},
#   {'pt2d': array([  78.7408371 , 1599.25488281]), 'track': None},
#   {'pt2d': array([  78.7408371 , 1599.25488281]), 'track': None},
#   {'pt2d': array([ 79.40023804, 476.40332031]), 'track': None},
#   {'pt2d': array([ 79.40023804, 476.40332031]),
#    'track': {'p_inA': array([ 24.12417754,  12.63432951, -44.01509646]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 294},
#      {'view_id': 1, 'feature_id': 542}]}},
#   {'pt2d': array([  79.40855408, 1028.5880127 ]),
#    'track': {'p_inA': array([-2.55175228,  0.30838941,  9.27555986]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 295},
#      {'view_id': 1, 'feature_id': 47}]}},
#   {'pt2d': array([ 79.8680191 , 755.58148193]), 'track': None},
#   {'pt2d': array([ 79.98535919, 404.12213135]),
#    'track': {'p_inA': array([-224.76997642, -284.1191385 ,  818.62269584]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 297},
#      {'view_id': 1, 'feature_id': 114},
#      {'view_id': 2, 'feature_id': 522}]}},
#   {'pt2d': array([  80.59688568, 1579.18737793]), 'track': None},
#   {'pt2d': array([ 80.92508698, 480.23822021]), 'track': None},
#   {'pt2d': array([  81.16536713, 1605.65026855]), 'track': None},
#   {'pt2d': array([ 81.31033325, 619.03668213]), 'track': None},
#   {'pt2d': array([ 81.49368286, 568.87683105]), 'track': None},
#   {'pt2d': array([  81.6785202 , 1661.53173828]), 'track': None},
#   {'pt2d': array([  81.6785202 , 1661.53173828]), 'track': None},
#   {'pt2d': array([ 82.07286835, 278.95147705]),
#    'track': {'p_inA': array([  55.4832797 ,   86.05190446, -201.91852887]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 305},
#      {'view_id': 1, 'feature_id': 113}]}},
#   {'pt2d': array([ 82.13874054, 872.03045654]),
#    'track': {'p_inA': array([-33.51233356,  -7.61828929, 122.58754082]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 306},
#      {'view_id': 1, 'feature_id': 156},
#      {'view_id': 2, 'feature_id': 517}]}},
#   {'pt2d': array([  82.55316162, 1674.4630127 ]), 'track': None},
#   {'pt2d': array([  82.82505035, 1001.26904297]),
#    'track': {'p_inA': array([-19.54452006,  -2.79327918,  -3.12237092]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 308},
#      {'view_id': 2, 'feature_id': 196}]}},
#   {'pt2d': array([ 82.84751129, 956.27575684]), 'track': None},
#   {'pt2d': array([  83.44232941, 1510.37109375]), 'track': None},
#   {'pt2d': array([  83.44232941, 1510.37109375]), 'track': None},
#   {'pt2d': array([  83.44232941, 1510.37109375]), 'track': None},
#   {'pt2d': array([  83.44232941, 1510.37109375]), 'track': None},
#   {'pt2d': array([ 83.64259338, 816.47521973]), 'track': None},
#   {'pt2d': array([ 83.94982147, 270.35690308]), 'track': None},
#   {'pt2d': array([ 84.08812714, 751.97021484]),
#    'track': {'p_inA': array([-35.90963379, -17.89806933, 132.01071453]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 316},
#      {'view_id': 1, 'feature_id': 154},
#      {'view_id': 2, 'feature_id': 527}]}},
#   {'pt2d': array([ 84.08812714, 751.97021484]),
#    'track': {'p_inA': array([-35.90963379, -17.89806933, 132.01071453]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 317},
#      {'view_id': 1, 'feature_id': 155},
#      {'view_id': 2, 'feature_id': 528}]}},
#   {'pt2d': array([  84.2649765 , 1070.83898926]), 'track': None},
#   {'pt2d': array([ 84.36091614, 861.28491211]),
#    'track': {'p_inA': array([-3.39212687e-02, -3.55903420e+01, -1.03945414e+02]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 319},
#      {'view_id': 2, 'feature_id': 333},
#      {'view_id': 0, 'feature_id': 2211},
#      {'view_id': 1, 'feature_id': 2}]}},
#   {'pt2d': array([ 84.37831116, 507.13546753]),
#    'track': {'p_inA': array([-48.97119561, -51.19062228, 180.07126108]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 320},
#      {'view_id': 1, 'feature_id': 131},
#      {'view_id': 2, 'feature_id': 525}]}},
#   {'pt2d': array([ 84.40718079, 455.85574341]),
#    'track': {'p_inA': array([-86.03481542, -99.92072846, 316.54869848]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 268},
#      {'view_id': 2, 'feature_id': 500},
#      {'view_id': 0, 'feature_id': 321},
#      {'view_id': 1, 'feature_id': 132}]}},
#   {'pt2d': array([ 84.95935059, 282.41818237]),
#    'track': {'p_inA': array([  49.22708346,   76.46046334, -180.10913929]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 322},
#      {'view_id': 1, 'feature_id': 117}]}},
#   {'pt2d': array([ 84.95935059, 282.41818237]),
#    'track': {'p_inA': array([  49.2270897 ,   76.46047304, -180.10916239]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 323},
#      {'view_id': 1, 'feature_id': 118},
#      {'view_id': 2, 'feature_id': 2012}]}},
#   {'pt2d': array([ 85.06812286, 270.62173462]),
#    'track': {'p_inA': array([  37.85088186,   59.82712778, -138.39110728]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 324},
#      {'view_id': 1, 'feature_id': 116}]}},
#   {'pt2d': array([  85.45137024, 1199.40966797]), 'track': None},
#   {'pt2d': array([ 85.4808197 , 986.78869629]), 'track': None},
#   {'pt2d': array([  85.75502777, 1562.4420166 ]), 'track': None},
#   {'pt2d': array([  85.75502777, 1562.4420166 ]), 'track': None},
#   {'pt2d': array([  85.88685608, 1194.89672852]), 'track': None},
#   {'pt2d': array([  85.88685608, 1194.89672852]), 'track': None},
#   {'pt2d': array([ 87.21335602, 829.70654297]), 'track': None},
#   {'pt2d': array([ 87.46443176, 378.91259766]),
#    'track': {'p_inA': array([-337.85668829, -325.96817515, -169.68481413]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 332},
#      {'view_id': 1, 'feature_id': 137},
#      {'view_id': 2, 'feature_id': 543}]}},
#   {'pt2d': array([ 87.54360962, 266.86642456]), 'track': None},
#   {'pt2d': array([ 87.60364532, 643.57244873]), 'track': None},
#   {'pt2d': array([  88.80086517, 1071.16674805]), 'track': None},
#   {'pt2d': array([ 88.90569305, 263.12097168]),
#    'track': {'p_inA': array([  96.90592997,  155.93972625, -358.2017517 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 336},
#      {'view_id': 1, 'feature_id': 125}]}},
#   {'pt2d': array([ 88.93339539, 747.43609619]), 'track': None},
#   {'pt2d': array([ 89.03588104, 270.22302246]),
#    'track': {'p_inA': array([ 18.67298785,  29.80148182, -68.58949909]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 338},
#      {'view_id': 1, 'feature_id': 133}]}},
#   {'pt2d': array([ 89.44774628, 642.02514648]),
#    'track': {'p_inA': array([-0.02087519, -0.02926033,  1.00341335]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 339},
#      {'view_id': 2, 'feature_id': 538},
#      {'view_id': 1, 'feature_id': 130}]}},
#   {'pt2d': array([ 89.61220551, 445.66925049]), 'track': None},
#   {'pt2d': array([ 90.17390442, 247.32302856]), 'track': None},
#   {'pt2d': array([  90.20236969, 1595.66955566]), 'track': None},
#   {'pt2d': array([ 90.49902344, 255.11439514]), 'track': None},
#   {'pt2d': array([ 91.06318665, 243.48716736]), 'track': None},
#   {'pt2d': array([ 91.28833008, 404.24761963]),
#    'track': {'p_inA': array([ 23.93773258,  31.08047277, -88.61255346]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 345},
#      {'view_id': 1, 'feature_id': 153},
#      {'view_id': 2, 'feature_id': 549}]}},
#   {'pt2d': array([  91.3598938 , 1324.94580078]), 'track': None},
#   {'pt2d': array([  91.3598938 , 1324.94580078]),
#    'track': {'p_inA': array([-3.97999275,  2.88139246, -5.49549766]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 347},
#      {'view_id': 1, 'feature_id': 970}]}},
#   {'pt2d': array([ 92.03032684, 350.8878479 ]),
#    'track': {'p_inA': array([-222.33200479, -314.90288965,  830.64343956]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 348},
#      {'view_id': 1, 'feature_id': 143},
#      {'view_id': 2, 'feature_id': 548}]}},
#   {'pt2d': array([  92.15299988, 1152.86865234]), 'track': None},
#   {'pt2d': array([  92.15299988, 1152.86865234]), 'track': None},
#   {'pt2d': array([  92.22701263, 1856.79174805]), 'track': None},
#   {'pt2d': array([ 92.31582642, 462.00942993]),
#    'track': {'p_inA': array([-17.66695295, -20.60363496,  66.11379482]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 352},
#      {'view_id': 1, 'feature_id': 122}]}},
#   {'pt2d': array([ 92.50597382, 264.73825073]),
#    'track': {'p_inA': array([  40.97637345,   66.41665682, -152.42588286]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 353},
#      {'view_id': 1, 'feature_id': 141}]}},
#   {'pt2d': array([ 92.69032288, 285.42437744]), 'track': None},
#   {'pt2d': array([ 93.03411865, 255.88067627]),
#    'track': {'p_inA': array([-0.08222962,  0.97734312, -1.39286858]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 355},
#      {'view_id': 2, 'feature_id': 475}]}},
#   {'pt2d': array([ 93.2689743 , 638.67675781]),
#    'track': {'p_inA': array([-35.07168476, -26.88813204, 131.61492639]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 356},
#      {'view_id': 1, 'feature_id': 167},
#      {'view_id': 2, 'feature_id': 1549}]}},
#   {'pt2d': array([ 93.32233429, 461.36950684]), 'track': None},
#   {'pt2d': array([  93.62268829, 1569.08190918]), 'track': None},
#   {'pt2d': array([  93.62268829, 1569.08190918]), 'track': None},
#   {'pt2d': array([ 93.97206879, 639.35998535]),
#    'track': {'p_inA': array([ 0.99372055,  0.77275553, -2.77315293]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 360},
#      {'view_id': 2, 'feature_id': 557},
#      {'view_id': 1, 'feature_id': 180}]}},
#   {'pt2d': array([  94.06577301, 1000.59002686]), 'track': None},
#   {'pt2d': array([  94.06858826, 1560.84350586]), 'track': None},
#   {'pt2d': array([  94.06858826, 1560.84350586]), 'track': None},
#   {'pt2d': array([ 94.44842529, 272.5463562 ]),
#    'track': {'p_inA': array([  74.58626722,  119.90011833, -279.17163351]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 364},
#      {'view_id': 1, 'feature_id': 145}]}},
#   {'pt2d': array([ 94.88276672, 788.50769043]),
#    'track': {'p_inA': array([-37.09596652, -15.76193094, 139.6634337 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 365},
#      {'view_id': 1, 'feature_id': 184},
#      {'view_id': 2, 'feature_id': 547}]}},
#   {'pt2d': array([  95.04956055, 1573.49621582]), 'track': None},
#   {'pt2d': array([ 95.11612701, 246.93135071]),
#    'track': {'p_inA': array([  63.05836229,  105.34437243, -236.32337569]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 367},
#      {'view_id': 1, 'feature_id': 146},
#      {'view_id': 2, 'feature_id': 1357}]}},
#   {'pt2d': array([ 95.11612701, 246.93135071]),
#    'track': {'p_inA': array([  63.05835701,  105.3443636 , -236.32335571]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 368},
#      {'view_id': 1, 'feature_id': 147}]}},
#   {'pt2d': array([  95.27796173, 1655.7064209 ]), 'track': None},
#   {'pt2d': array([ 95.4274826 , 656.80609131]),
#    'track': {'p_inA': array([-436.97449513,  140.1398853 ,  -46.42311588]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 370},
#      {'view_id': 2, 'feature_id': 314}]}},
#   {'pt2d': array([ 95.57817841, 266.59564209]), 'track': None},
#   {'pt2d': array([  95.76485443, 1016.45898438]), 'track': None},
#   {'pt2d': array([  95.76485443, 1016.45898438]),
#    'track': {'p_inA': array([ 8.01405188, -2.01034757, -5.39391005]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 373},
#      {'view_id': 1, 'feature_id': 715}]}},
#   {'pt2d': array([  95.76686859, 1585.3659668 ]), 'track': None},
#   {'pt2d': array([ 96.61687469, 454.98547363]),
# ...
#      {'view_id': 1, 'feature_id': 1359},
#      {'view_id': 2, 'feature_id': 2033}]}},
#   {'pt2d': array([224.08447266, 519.85198975]),
#    'track': {'p_inA': array([-43.80257097, -64.71934209, 234.21169088]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 861},
#      {'view_id': 1, 'feature_id': 360}]}},
#   {'pt2d': array([ 224.36299133, 1564.48034668]), 'track': None},
#   {'pt2d': array([ 224.36299133, 1564.48034668]), 'track': None},
#   {'pt2d': array([224.89176941, 803.64276123]), 'track': None},
#   {'pt2d': array([224.89176941, 803.64276123]), 'track': None},
#   {'pt2d': array([224.89176941, 803.64276123]), 'track': None},
#   {'pt2d': array([ 224.89694214, 1866.60778809]), 'track': None},
#   {'pt2d': array([ 224.94506836, 1584.31384277]),
#    'track': {'p_inA': array([-227.48788022,   18.19212173,  -29.41219855]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 868},
#      {'view_id': 2, 'feature_id': 955}]}},
#   {'pt2d': array([225.29301453, 951.12878418]), 'track': None},
#   {'pt2d': array([225.29301453, 951.12878418]), 'track': None},
#   {'pt2d': array([225.29301453, 951.12878418]), 'track': None},
#   {'pt2d': array([ 225.45603943, 1591.72521973]), 'track': None},
#   {'pt2d': array([226.09054565, 485.58624268]), 'track': None},
#   {'pt2d': array([226.60995483, 959.56842041]), 'track': None},
#   {'pt2d': array([226.65663147, 316.28503418]), 'track': None},
#   {'pt2d': array([ 226.90744019, 1598.70458984]), 'track': None},
#   {'pt2d': array([ 226.90744019, 1598.70458984]), 'track': None},
#   {'pt2d': array([227.17913818, 522.625     ]),
#    'track': {'p_inA': array([-0.23497932, -0.34891819,  1.26999267]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 878},
#      {'view_id': 2, 'feature_id': 700}]}},
#   {'pt2d': array([227.40716553, 782.08392334]), 'track': None},
#   {'pt2d': array([227.64292908, 962.52996826]), 'track': None},
#   {'pt2d': array([227.64292908, 962.52996826]), 'track': None},
#   {'pt2d': array([ 227.86798096, 1575.7286377 ]), 'track': None},
#   {'pt2d': array([ 229.43173218, 1839.96911621]), 'track': None},
#   {'pt2d': array([ 229.43173218, 1839.96911621]), 'track': None},
#   {'pt2d': array([ 229.8127594 , 1008.17303467]),
#    'track': {'p_inA': array([-3.45427499,  0.40075001, 18.83805988]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 885},
#      {'view_id': 1, 'feature_id': 362},
#      {'view_id': 2, 'feature_id': 64}]}},
#   {'pt2d': array([ 229.9881134 , 1864.41967773]),
#    'track': {'p_inA': array([-242.94522019,   24.27803233,  -39.92670953]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 886},
#      {'view_id': 2, 'feature_id': 942}]}},
#   {'pt2d': array([230.23283386, 863.42059326]), 'track': None},
#   {'pt2d': array([ 230.25012207, 1054.73620605]), 'track': None},
#   {'pt2d': array([ 230.26992798, 1001.96691895]),
#    'track': {'p_inA': array([-19.89634024,   1.90963206, 108.67810255]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 889},
#      {'view_id': 1, 'feature_id': 382},
#      {'view_id': 2, 'feature_id': 1910}]}},
#   {'pt2d': array([ 230.44448853, 1044.59411621]), 'track': None},
#   {'pt2d': array([ 230.44448853, 1044.59411621]), 'track': None},
#   {'pt2d': array([230.84056091, 800.69403076]), 'track': None},
#   {'pt2d': array([231.30249023, 534.36291504]), 'track': None},
#   {'pt2d': array([232.26010132, 924.5123291 ]),
#    'track': {'p_inA': array([-12.53003737,  -2.02593563,  68.87298597]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 894},
#      {'view_id': 1, 'feature_id': 381},
#      {'view_id': 2, 'feature_id': 646},
#      {'view_id': 1, 'feature_id': 107}]}},
#   {'pt2d': array([232.26724243, 231.37953186]), 'track': None},
#   {'pt2d': array([232.26724243, 231.37953186]), 'track': None},
#   {'pt2d': array([232.493927  , 994.04412842]),
#    'track': {'p_inA': array([-0.4959487 ,  0.03544384,  2.72978283]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 897},
#      {'view_id': 1, 'feature_id': 57}]}},
#   {'pt2d': array([232.9152832 , 964.90283203]), 'track': None},
#   {'pt2d': array([232.9152832 , 964.90283203]), 'track': None},
#   {'pt2d': array([ 233.09750366, 1136.59741211]), 'track': None},
#   {'pt2d': array([ 233.09750366, 1136.59741211]), 'track': None},
#   {'pt2d': array([ 234.260849  , 1899.82348633]), 'track': None},
#   {'pt2d': array([ 235.31611633, 1070.85620117]), 'track': None},
#   {'pt2d': array([ 235.60630798, 1561.95629883]), 'track': None},
#   {'pt2d': array([ 235.60630798, 1561.95629883]), 'track': None},
#   {'pt2d': array([235.67195129, 994.61022949]),
#    'track': {'p_inA': array([-12.01254865,  12.2806033 , -13.15231492]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 906},
#      {'view_id': 2, 'feature_id': 919}]}},
#   {'pt2d': array([235.89234924, 332.68063354]), 'track': None},
#   {'pt2d': array([237.1681366, 762.215271 ]),
#    'track': {'p_inA': array([-20.33992248, -14.58748752, 113.56915181]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 908},
#      {'view_id': 1, 'feature_id': 384}]}},
#   {'pt2d': array([237.48771667, 929.99023438]),
#    'track': {'p_inA': array([-0.97628699, -0.1112359 ,  5.50587408]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 909},
#      {'view_id': 2, 'feature_id': 926},
#      {'view_id': 1, 'feature_id': 318}]}},
#   {'pt2d': array([ 237.59020996, 1585.84472656]), 'track': None},
#   {'pt2d': array([ 237.59020996, 1585.84472656]), 'track': None},
#   {'pt2d': array([ 237.91583252, 1862.07019043]), 'track': None},
#   {'pt2d': array([ 237.91583252, 1862.07019043]), 'track': None},
#   {'pt2d': array([ 237.91583252, 1862.07019043]), 'track': None},
#   {'pt2d': array([238.00805664, 991.90100098]), 'track': None},
#   {'pt2d': array([ 238.4743042, 1826.3918457]), 'track': None},
#   {'pt2d': array([239.19122314, 533.34411621]),
#    'track': {'p_inA': array([  2.72630276,   4.47825914, -14.2347661 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 917},
#      {'view_id': 2, 'feature_id': 962}]}},
#   {'pt2d': array([239.19122314, 533.34411621]),
#    'track': {'p_inA': array([-43.00372992, -64.77766264, 241.69022501]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 918},
#      {'view_id': 1, 'feature_id': 380},
#      {'view_id': 2, 'feature_id': 963}]}},
#   {'pt2d': array([239.28637695, 349.25973511]),
#    'track': {'p_inA': array([ 10.00946742,  21.17912425, -55.0843711 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 919},
#      {'view_id': 1, 'feature_id': 371},
#      {'view_id': 2, 'feature_id': 966}]}},
#   {'pt2d': array([ 239.72924805, 1007.17028809]), 'track': None},
#   {'pt2d': array([ 241.00236511, 1839.87304688]), 'track': None},
#   {'pt2d': array([ 241.00236511, 1839.87304688]), 'track': None},
#   {'pt2d': array([ 241.49180603, 1827.69726562]), 'track': None},
#   {'pt2d': array([ 242.14439392, 1817.98266602]),
#    'track': {'p_inA': array([-11.83198367,  34.62900593,  67.31908506]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 924},
#      {'view_id': 1, 'feature_id': 419}]}},
#   {'pt2d': array([242.22779846, 771.25012207]), 'track': None},
#   {'pt2d': array([ 242.30558777, 1856.0065918 ]), 'track': None},
#   {'pt2d': array([ 242.3354187, 1490.1015625]), 'track': None},
#   {'pt2d': array([ 242.42791748, 1035.2088623 ]), 'track': None},
#   {'pt2d': array([ 242.42791748, 1035.2088623 ]), 'track': None},
#   {'pt2d': array([242.78024292, 785.47875977]),
#    'track': {'p_inA': array([-19.5583234 , -12.72563224, 111.34695903]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 930},
#      {'view_id': 1, 'feature_id': 394}]}},
#   {'pt2d': array([242.81741333, 937.71063232]), 'track': None},
#   {'pt2d': array([243.16127014, 990.80609131]), 'track': None},
#   {'pt2d': array([ 243.756073 , 1859.9074707]), 'track': None},
#   {'pt2d': array([ 243.756073 , 1859.9074707]), 'track': None},
#   {'pt2d': array([ 244.03041077, 1871.47570801]), 'track': None},
#   {'pt2d': array([ 244.2035675 , 1191.01025391]),
#    'track': {'p_inA': array([-5.07869746,  3.8047506 , -1.0768431 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 936},
#      {'view_id': 1, 'feature_id': 1384}]}},
#   {'pt2d': array([ 244.53204346, 1766.85253906]),
#    'track': {'p_inA': array([-861.07277033, 3522.51367318, 7580.97938722]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 937},
#      {'view_id': 1, 'feature_id': 81}]}},
#   {'pt2d': array([ 244.53204346, 1766.85253906]), 'track': None},
#   {'pt2d': array([ 244.94390869, 1854.07263184]), 'track': None},
#   {'pt2d': array([245.39665222, 922.58905029]),
#    'track': {'p_inA': array([-10.44827787,  -1.86163014,  60.07323063]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 940},
#      {'view_id': 1, 'feature_id': 398}]}},
#   {'pt2d': array([245.96907043, 992.17724609]), 'track': None},
#   {'pt2d': array([ 246.04995728, 1076.8125    ]),
#    'track': {'p_inA': array([-79.49409894, -34.9261203 , -10.82726006]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 942},
#      {'view_id': 2, 'feature_id': 290}]}},
#   {'pt2d': array([ 246.04995728, 1076.8125    ]), 'track': None},
#   {'pt2d': array([ 246.41304016, 1065.53894043]), 'track': None},
#   {'pt2d': array([ 246.41304016, 1065.53894043]), 'track': None},
#   {'pt2d': array([246.74188232, 356.90563965]), 'track': None},
#   {'pt2d': array([ 246.98765564, 1554.09997559]), 'track': None},
#   {'pt2d': array([ 246.98765564, 1554.09997559]), 'track': None},
#   {'pt2d': array([ 247.0824585 , 1010.90142822]), 'track': None},
#   {'pt2d': array([ 247.0824585 , 1010.90142822]), 'track': None},
#   {'pt2d': array([247.10916138, 335.73995972]),
#    'track': {'p_inA': array([  37.44497975,   84.27262124, -215.06603974]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 951},
#      {'view_id': 1, 'feature_id': 386}]}},
#   {'pt2d': array([ 247.39752197, 1898.59204102]), 'track': None},
#   {'pt2d': array([247.61567688, 364.32678223]), 'track': None},
#   {'pt2d': array([247.74189758, 372.5534668 ]), 'track': None},
#   {'pt2d': array([ 247.84986877, 1852.05541992]), 'track': None},
#   {'pt2d': array([ 247.84986877, 1852.05541992]), 'track': None},
#   {'pt2d': array([ 247.84986877, 1852.05541992]), 'track': None},
#   {'pt2d': array([247.85366821, 372.26937866]),
#    'track': {'p_inA': array([ 0.15210215,  0.09197147, -0.04530949]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 958},
#      {'view_id': 1, 'feature_id': 220}]}},
#   {'pt2d': array([ 247.89903259, 1433.52172852]), 'track': None},
#   {'pt2d': array([247.92402649, 323.17929077]),
#    'track': {'p_inA': array([-204.16235732, -469.31598981, 1184.41914053]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 960},
#      {'view_id': 1, 'feature_id': 387}]}},
#   {'pt2d': array([248.23991394, 414.35543823]), 'track': None},
#   {'pt2d': array([248.41181946, 381.18917847]), 'track': None},
#   {'pt2d': array([248.41442871, 335.86956787]), 'track': None},
#   {'pt2d': array([ 250.03488159, 1864.9942627 ]), 'track': None},
#   {'pt2d': array([250.1313324 , 765.02661133]),
#    'track': {'p_inA': array([-3806.01199712,  2000.5004989 ,  -496.10665709]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 965},
#      {'view_id': 1, 'feature_id': 69}]}},
#   {'pt2d': array([250.1313324 , 765.02661133]),
#    'track': {'p_inA': array([-20.06736179, -14.84820614, 117.18009719]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 966},
#      {'view_id': 1, 'feature_id': 402},
#      {'view_id': 2, 'feature_id': 981}]}},
#   {'pt2d': array([ 250.37995911, 1573.05078125]), 'track': None},
#   {'pt2d': array([250.46533203, 349.26431274]), 'track': None},
#   {'pt2d': array([ 250.95387268, 1577.7052002 ]), 'track': None},
#   {'pt2d': array([ 250.95387268, 1577.7052002 ]),
#    'track': {'p_inA': array([-51.12684176,  29.01528344, -18.20998206]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 970},
#      {'view_id': 1, 'feature_id': 1015},
#      {'view_id': 2, 'feature_id': 1642}]}},
#   {'pt2d': array([ 250.95387268, 1577.7052002 ]), 'track': None},
#   {'pt2d': array([251.01344299, 378.81478882]),
#    'track': {'p_inA': array([-1286.10169717,  -776.38120813,  3601.68213894]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 972},
#      {'view_id': 2, 'feature_id': 1968}]}},
#   {'pt2d': array([251.05145264, 396.93634033]),
#    'track': {'p_inA': array([ 2.65493272,  1.53299358, 44.62307541]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 973},
#      {'view_id': 2, 'feature_id': 1927},
#      {'view_id': 0, 'feature_id': 2142},
#      {'view_id': 1, 'feature_id': 1135}]}},
#   {'pt2d': array([251.12016296, 336.47531128]),
#    'track': {'p_inA': array([ 111.35552404,  253.63464337, -650.1453647 ]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 974},
#      {'view_id': 1, 'feature_id': 392}]}},
#   {'pt2d': array([ 251.38357544, 1848.96276855]), 'track': None},
#   {'pt2d': array([251.80281067, 926.13134766]), 'track': None},
#   {'pt2d': array([252.02688599, 331.27346802]),
#    'track': {'p_inA': array([-167.51524732, -384.59373346,  983.49118295]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 977},
#      {'view_id': 1, 'feature_id': 393}]}},
#   {'pt2d': array([ 252.19392395, 1051.15454102]), 'track': None},
#   {'pt2d': array([252.22032166, 362.04541016]),
#    'track': {'p_inA': array([ 144.24117845,  316.48182062, -845.55953848]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 979},
#      {'view_id': 1, 'feature_id': 395},
#      {'view_id': 2, 'feature_id': 1035}]}},
#   {'pt2d': array([252.28004456, 374.15115356]),
#    'track': {'p_inA': array([  2.1584755 ,   5.37518719, -11.85747388]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 980},
#      {'view_id': 2, 'feature_id': 1065}]}},
#   {'pt2d': array([ 252.41107178, 1761.94921875]), 'track': None},
#   {'pt2d': array([252.53012085, 799.31939697]), 'track': None},
#   {'pt2d': array([ 252.54571533, 1077.15380859]), 'track': None},
#   {'pt2d': array([ 252.54571533, 1077.15380859]), 'track': None},
#   {'pt2d': array([ 255.00289917, 1885.60668945]), 'track': None},
#   {'pt2d': array([ 255.34352112, 1875.88891602]), 'track': None},
#   {'pt2d': array([256.70516968, 259.17074585]),
#    'track': {'p_inA': array([  47.07848113,  122.59570942, -279.89744829]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 987},
#      {'view_id': 1, 'feature_id': 397}]}},
#   {'pt2d': array([256.71563721, 938.14416504]),
#    'track': {'p_inA': array([-16.79860715,  -2.14896714, 100.57893453]),
#     'valid': True,
#     'matches': [{'view_id': 0, 'feature_id': 988},
#      {'view_id': 1, 'feature_id': 412}]}},
#   {'pt2d': array([ 256.78414917, 1521.93212891]), 'track': None},
#   {'pt2d': array([ 256.78414917, 1521.93212891]), 'track': None},
#   {'pt2d': array([256.8163147 , 221.27798462]),
#    'track': {'p_inA': array([-0.07455257, -0.41965938,  0.65577215]),
#     'valid': False,
#     'matches': [{'view_id': 0, 'feature_id': 991},
#      {'view_id': 2, 'feature_id': 1713},
#      {'view_id': 1, 'feature_id': 309}]}},
#   {'pt2d': array([ 256.82867432, 1126.64306641]), 'track': None},
#   {'pt2d': array([ 256.82867432, 1126.64306641]), 'track': None},
#   {'pt2d': array([257.11279297, 951.48040771]), 'track': None},
#   {'pt2d': array([257.7539978 , 535.31939697]), 'track': None},
#   {'pt2d': array([ 258.93048096, 1877.61730957]), 'track': None},
#   {'pt2d': array([ 258.93048096, 1877.61730957]), 'track': None},
#   {'pt2d': array([ 259.69293213, 1621.38330078]), 'track': None},
#   {'pt2d': array([ 259.9468689 , 1497.74084473]), 'track': None},
#   ...],
#  'desc': array([[ 62.,  27.,   1., ...,  16.,  24.,  88.],
#         [ 61.,  19.,  26., ...,   2.,   1.,   1.],
#         [  3.,   3.,   2., ...,  44.,  50.,  32.],
#         ...,
#         [ 41., 123.,  34., ...,   1.,  15.,  21.],
#         [  1.,   1.,  18., ..., 123.,  31.,  12.],
#         [  5.,  26.,   7., ...,  19.,   1.,   3.]], dtype=float32)}

# %%
sfm.visualize_results(views, tracks, K, frames_per_second)

# %% [markdown]
# Copy results. If you want to start again from here, do the following:
#
# ```python
# views, tracks = sfm.copy_results(views_2_opt, tracks_2_opt)
# ```

# %%
views_2_opt, tracks_2_opt = sfm.copy_results(views, tracks)

# %% [markdown]
# ## All Resectioning Steps w/out Plots

# %%
iC = sfm.add_next_view(views, tracks, K, matching_threshold=matching_threshold)
tracks_to_resection = []
tracks_to_triangulate = []
for track in tracks:
    if not track['valid']:
        continue
    
    match = sfm.get_match_with_view_id(track['matches'], iC)
    if match is None:
        continue

    if track['p_inA'] is None:
        tracks_to_triangulate.append(track)
    else:
        tracks_to_resection.append(track)

print(f'{len(tracks_to_resection)} tracks to resection')
print(f'{len(tracks_to_triangulate)} tracks to triangulate')
p_inA = []
c = []
for track in tracks_to_resection:
    assert(track['p_inA'] is not None)
    p_inA.append(track['p_inA'])
    match = sfm.get_match_with_view_id(track['matches'], iC)
    c.append(sfm.get_pt2d_from_match(views, match))
p_inA = np.array(p_inA)
c = np.array(c)

print(f'len(p_inA) = {len(p_inA)}, len(c) = {len(c)}')
R_inC_ofA, p_inC_ofA, num_inliers, mask = sfm.resection(
    p_inA,
    c,
    K,
    rng,
    threshold=1.5,
    num_iters=8000,
)
print(f'found {num_inliers} inliers out of {len(mask)}')
views[iC]['R_inB_ofA'] = R_inC_ofA
views[iC]['p_inB_ofA'] = p_inC_ofA
for track in tracks_to_triangulate:
    p_inA = sfm.triangulate(track, views, K)
    track['p_inA'] = p_inA
views_2_ini, tracks_2_ini = sfm.copy_results(views, tracks)

optimizer, initial_values = sfm.get_optimizer(views, tracks, K)

result = optimizer.optimize(initial_values)
assert(result.status == symforce.opt.optimizer.Optimizer.Status.SUCCESS)

sfm.store_results(views, tracks, K, result, max_reprojection_err=max_reprojection_err)

sfm.visualize_results(views, tracks, K, frames_per_second)

views_2_opt, tracks_2_opt = sfm.copy_results(views, tracks)
# Out:
# ADDING VIEW 3
# [2024-04-28T03:32:04Z WARN  re_sdk_comms::buffered_client] Failed to send message after 3 attempts: Failed to send to Rerun server at 127.0.0.1:9876: Broken pipe (os error 32)
# matching image 0 with image 3 with threshold 0.9:
#   450 good matches found
#        FOUND INCONSISTENT - ( 0,  823) ( 1,  358) ( 2,  444) ( 2,  890) ( 1,   89) ( 3, 1922)
#        FOUND INCONSISTENT - ( 0,   34) ( 1,   10) ( 2,  523) ( 1,   96) ( 3,  890)
#        FOUND INCONSISTENT - ( 0, 1588) ( 2,   36) ( 0, 1546) ( 1,  710) ( 3, 1527)
#        FOUND INCONSISTENT - ( 0, 1490) ( 1,  694) ( 2, 1382) ( 2, 1383) ( 3, 3161)
#        FOUND INCONSISTENT - ( 0, 1563) ( 1,  845) ( 2, 1447) ( 2, 1558) ( 3, 3280)
#        FOUND INCONSISTENT - ( 0,  461) ( 1,  213) ( 2, 2055) ( 1, 1362) ( 3, 1368)
#        FOUND INCONSISTENT - ( 0,  268) ( 2,  500) ( 0,  321) ( 1,  132) ( 3, 1204)
#        FOUND INCONSISTENT - ( 0, 1249) ( 1,  562) ( 2, 1236) ( 2, 1249) ( 3, 2749)
#        FOUND INCONSISTENT - ( 0,  822) ( 1, 1195) ( 2,  864) ( 2, 1832) ( 3, 1924)
#        FOUND INCONSISTENT - ( 0, 2346) ( 2, 1914) ( 0, 2399) ( 1, 1193) ( 3, 4868)
#        FOUND INCONSISTENT - ( 0,  849) ( 1,  356) ( 2,  897) ( 2,  172) ( 3, 1997)
#   251 tracks created
#     0 tracks in C extended with point in B
#   199 tracks in B extended with point in C
#     0 tracks merged (trivial)
#     0 tracks merged (non-trivial)
#    11 inconsistent tracks
#
# matching image 1 with image 3 with threshold 0.9:
#   401 good matches found
#        trivial merge - ( 1, 1141) ( 3, 4328) - ( 0, 2149) ( 1, 1141) ( 2, 1770) ( 3, 4328)
#        trivial merge - ( 1,  394) ( 3, 2107) - ( 0,  930) ( 1,  394) ( 3, 2107)
#        trivial merge - ( 1,  200) ( 3, 1376) - ( 0,  451) ( 1,  200) ( 2,  598) ( 3, 1376)
#        FOUND INCONSISTENT - ( 0, 1769) ( 1,  913) ( 3, 4671) ( 3, 3803)
#        trivial merge - ( 1, 1263) ( 3, 4811) - ( 0, 2367) ( 1, 1263) ( 2, 1921) ( 3, 4811)
#        non-trivial merge - matches ( 1, 1114) ( 3, 4357)
#                            track one ( 0, 1511) ( 2, 1443) ( 0, 2646) ( 1, 1114)
#                            track two ( 0, 2651) ( 3, 4357)
#                            => ( 0, 2651) ( 3, 4357) ( 0, 1511) ( 2, 1443) ( 0, 2646) ( 1, 1114)  - False
#        FOUND INCONSISTENT - ( 0, 2651) ( 3, 4357) ( 0, 1511) ( 2, 1443) ( 0, 2646) ( 1, 1114)
#        trivial merge - ( 1,  296) ( 3, 1607) - ( 0,  640) ( 1,  296) ( 2,  707) ( 3, 1607)
#        trivial merge - ( 1,  358) ( 3, 1922) - ( 0,  823) ( 1,  358) ( 2,  444) ( 2,  890) ( 1,   89) ( 3, 1922)
#        trivial merge - ( 1,   84) ( 3, 1156) - ( 0,  230) ( 1,   84) ( 3, 1156)
#        trivial merge - ( 1,  243) ( 3, 1433) - ( 0,  538) ( 1,  243) ( 2,  623) ( 3, 1433)
#        trivial merge - ( 1,   93) ( 3, 1118) - ( 0,  200) ( 1,   93) ( 2,  454) ( 3, 1118)
#        trivial merge - ( 1,  286) ( 3, 1553) - ( 0,  609) ( 1,  286) ( 2,  686) ( 3, 1553)
#        trivial merge - ( 1, 1184) ( 3, 4460) - ( 0, 2180) ( 1, 1184) ( 2, 1798) ( 3, 4460)
#        trivial merge - ( 1,  335) ( 3, 1815) - ( 0,  753) ( 1,  335) ( 2,  801) ( 3, 1815)
#        trivial merge - ( 1,  371) ( 3, 2116) - ( 0,  919) ( 1,  371) ( 2,  966) ( 3, 2116)
#        trivial merge - ( 1,  869) ( 3, 4041) - ( 0, 1793) ( 1,  869) ( 3, 4041)
#        non-trivial merge - matches ( 1, 1444) ( 3, 4514)
#                            track one ( 0, 2125) ( 1, 1444)
#                            track two ( 0, 2314) ( 1,  856) ( 3, 4514)
#                            => ( 0, 2314) ( 1,  856) ( 3, 4514) ( 0, 2125) ( 1, 1444)  - False
#        FOUND INCONSISTENT - ( 0, 2314) ( 1,  856) ( 3, 4514) ( 0, 2125) ( 1, 1444)
#        trivial merge - ( 1,  384) ( 3, 2070) - ( 0,  908) ( 1,  384) ( 3, 2070)
#        trivial merge - ( 1, 1248) ( 3, 4642) - ( 0, 2321) ( 1, 1248) ( 2, 1869) ( 3, 4642)
#        trivial merge - ( 1,   94) ( 3, 1119) - ( 0,  201) ( 1,   94) ( 2,  455) ( 3, 1119)
#        FOUND INCONSISTENT - ( 0,  894) ( 1,  381) ( 2,  646) ( 1,  107) ( 3, 1154)
#        FOUND INCONSISTENT - ( 0,  612) ( 1,  268) ( 3, 1569) ( 3, 1568)
#        trivial merge - ( 1,  611) ( 3, 2995) - ( 0, 1344) ( 1,  611) ( 2, 1321) ( 3, 2995)
#        FOUND INCONSISTENT - ( 0,  506) ( 1,  245) ( 2,  292) ( 3, 1416) ( 3, 1413)
#        trivial merge - ( 1,  106) ( 3, 1223) - ( 0,  284) ( 1,  106) ( 2,  519) ( 3, 1223)
#        trivial merge - ( 1,  710) ( 3, 1527) - ( 0, 1588) ( 2,   36) ( 0, 1546) ( 1,  710) ( 3, 1527)
#        FOUND INCONSISTENT - ( 0, 2800) ( 1, 1452) ( 2, 1909) ( 1,  760) ( 3, 3367)
#        trivial merge - ( 1,  370) ( 3, 1970) - ( 0,  856) ( 1,  370) ( 2,  884) ( 3, 1970)
#        FOUND INCONSISTENT - ( 0, 2721) ( 1,  197) ( 2,  102) ( 3,  538) ( 3, 2881)
#        trivial merge - ( 1, 1275) ( 3, 4789) - ( 0, 2385) ( 1, 1275) ( 2, 1913) ( 3, 4789)
#        non-trivial merge - matches ( 1,  398) ( 3, 2340)
#                            track one ( 0,  940) ( 1,  398)
#                            track two ( 0,  279) ( 3, 2340)
#                            => ( 0,  279) ( 3, 2340) ( 0,  940) ( 1,  398)  - True
#        FOUND INCONSISTENT - ( 0,  279) ( 3, 2340) ( 0,  940) ( 1,  398)
#        trivial merge - ( 1,  247) ( 3, 1512) - ( 0,  572) ( 1,  247) ( 2,  679) ( 3, 1512)
#        trivial merge - ( 1, 1145) ( 3, 4351) - ( 0, 2162) ( 1, 1145) ( 2, 1778) ( 3, 4351)
#        FOUND INCONSISTENT - ( 0,  889) ( 1,  382) ( 2, 1910) ( 3, 2554) ( 1,  502)
#        trivial merge - ( 1,  650) ( 3, 3005) - ( 0, 1407) ( 1,  650) ( 2, 1323) ( 3, 3005)
#        trivial merge - ( 1,  301) ( 3, 1641) - ( 0,  659) ( 1,  301) ( 3, 1641)
#        trivial merge - ( 1,   62) ( 3, 1102) - ( 0,  177) ( 1,   62) ( 2,  448) ( 3, 1102)
#        trivial merge - ( 1,  682) ( 3, 3083) - ( 0, 1457) ( 1,  682) ( 2, 1362) ( 3, 3083)
#        FOUND INCONSISTENT - ( 0,  909) ( 2,  926) ( 1,  318) ( 3, 2063) ( 1,  389)
#        non-trivial merge - matches ( 1,  655) ( 3, 3159)
#                            track one ( 1,  655) ( 2, 1393)
#                            track two ( 0, 1439) ( 3, 3159)
#                            => ( 0, 1439) ( 3, 3159) ( 1,  655) ( 2, 1393)  - False
#        trivial merge - ( 1,  105) ( 3, 1147) - ( 0,  225) ( 1,  105) ( 2,  927) ( 3, 1147)
#        trivial merge - ( 1, 1082) ( 3, 4143) - ( 0, 2046) ( 1, 1082) ( 2, 1706) ( 3, 4143)
#        trivial merge - ( 1,  212) ( 3, 1390) - ( 0,  488) ( 1,  212) ( 2,  605) ( 3, 1390)
#        trivial merge - ( 1,  960) ( 3, 3927) - ( 0, 1862) ( 1,  960) ( 2, 1643) ( 3, 3927)
#        trivial merge - ( 1,  554) ( 3, 2738) - ( 0, 1232) ( 1,  554) ( 2, 1228) ( 3, 2738)
#        trivial merge - ( 1,  153) ( 3, 1291) - ( 0,  345) ( 1,  153) ( 2,  549) ( 3, 1291)
#        trivial merge - ( 1,  336) ( 3, 1803) - ( 0,  752) ( 1,  336) ( 2,  799) ( 3, 1803)
#        trivial merge - ( 1,  430) ( 3, 2424) - ( 0, 1065) ( 1,  430) ( 2, 1115) ( 3, 2424)
#        trivial merge - ( 1,  334) ( 3, 1766) - ( 0,  735) ( 1,  334) ( 3, 1766)
#        trivial merge - ( 1,   37) ( 3, 1056) - ( 0,  129) ( 1,   37) ( 2,  416) ( 3, 1056)
#        trivial merge - ( 1,  380) ( 3, 2119) - ( 0,  918) ( 1,  380) ( 2,  963) ( 3, 2119)
#        FOUND INCONSISTENT - ( 0, 2103) ( 1, 1036) ( 3, 3452) ( 3, 4109)
#        trivial merge - ( 1, 1174) ( 3, 4421) - ( 0, 2203) ( 1, 1174) ( 2, 1800) ( 3, 4421)
#        trivial merge - ( 1, 1110) ( 3, 4202) - ( 0, 2083) ( 1, 1110) ( 2, 1731) ( 3, 4202)
#        trivial merge - ( 1,  498) ( 3, 2699) - ( 0, 1177) ( 1,  498) ( 2, 1219) ( 3, 2699)
#        trivial merge - ( 1,  471) ( 3, 2604) - ( 0, 1137) ( 1,  471) ( 2, 1181) ( 3, 2604)
#        non-trivial merge - matches ( 1,  300) ( 3,   70)
#                            track one ( 0,  529) ( 1,  300)
#                            track two ( 0,  530) ( 3,   70)
#                            => ( 0,  530) ( 3,   70) ( 0,  529) ( 1,  300)  - True
#        FOUND INCONSISTENT - ( 0,  530) ( 3,   70) ( 0,  529) ( 1,  300)
#        trivial merge - ( 1,  802) ( 3, 3400) - ( 0, 1633) ( 1,  802) ( 2, 1481) ( 3, 3400)
#        trivial merge - ( 1,  174) ( 3, 1320) - ( 0,  399) ( 1,  174) ( 2,  573) ( 3, 1320)
#        non-trivial merge - matches ( 1, 1448) ( 3, 4832)
#                            track one ( 0, 2410) ( 1, 1448)
#                            track two ( 0, 1969) ( 3, 4832)
#                            => ( 0, 1969) ( 3, 4832) ( 0, 2410) ( 1, 1448)  - False
#        FOUND INCONSISTENT - ( 0, 1969) ( 3, 4832) ( 0, 2410) ( 1, 1448)
#        FOUND INCONSISTENT - ( 0,  894) ( 1,  381) ( 2,  646) ( 1,  107) ( 3, 1154) ( 3, 1029)
#        trivial merge - ( 1, 1153) ( 3, 4339) - ( 0, 2169) ( 1, 1153) ( 3, 4339)
#        FOUND INCONSISTENT - ( 0, 2036) ( 1, 1385) ( 3, 4528) ( 1,  799)
#        trivial merge - ( 1,  803) ( 3, 3401) - ( 0, 1634) ( 1,  803) ( 3, 3401)
#        FOUND INCONSISTENT - ( 0,  570) ( 1,  222) ( 2,   13) ( 2,  607) ( 3, 1412)
#        trivial merge - ( 1,  251) ( 3, 1507) - ( 0,  577) ( 1,  251) ( 2,  676) ( 3, 1507)
#        trivial merge - ( 1,  482) ( 3, 2626) - ( 0, 1145) ( 1,  482) ( 2, 1190) ( 3, 2626)
#        trivial merge - ( 1,  156) ( 3, 1230) - ( 0,  306) ( 1,  156) ( 2,  517) ( 3, 1230)
#        trivial merge - ( 1,  609) ( 3, 2993) - ( 0,  485) ( 1,  609) ( 3, 2993)
#        trivial merge - ( 1,  101) ( 3, 1201) - ( 0,  271) ( 1,  101) ( 2,  506) ( 3, 1201)
#        non-trivial merge - matches ( 1, 1297) ( 3, 4690)
#                            track one ( 0, 2516) ( 1, 1297) ( 2, 2016)
#                            track two ( 0, 2343) ( 3, 4690)
#                            => ( 0, 2343) ( 3, 4690) ( 0, 2516) ( 1, 1297) ( 2, 2016)  - False
#        FOUND INCONSISTENT - ( 0, 2343) ( 3, 4690) ( 0, 2516) ( 1, 1297) ( 2, 2016)
#        non-trivial merge - matches ( 1,  116) ( 3, 1046)
#                            track one ( 0,  324) ( 1,  116)
#                            track two ( 0,  390) ( 3, 1046)
#                            => ( 0,  390) ( 3, 1046) ( 0,  324) ( 1,  116)  - False
#        FOUND INCONSISTENT - ( 0,  390) ( 3, 1046) ( 0,  324) ( 1,  116)
#        trivial merge - ( 1,  521) ( 3, 2765) - ( 0, 1217) ( 1,  521) ( 3, 2765)
#        non-trivial merge - matches ( 1, 1176) ( 3, 4507)
#                            track one ( 0, 2198) ( 1, 1176) ( 2, 1838)
#                            track two ( 0, 2070) ( 2, 1757) ( 1, 1059) ( 3, 4507)
#                            => ( 0, 2070) ( 2, 1757) ( 1, 1059) ( 3, 4507) ( 0, 2198) ( 1, 1176) ( 2, 1838)  - False
#        FOUND INCONSISTENT - ( 0, 2070) ( 2, 1757) ( 1, 1059) ( 3, 4507) ( 0, 2198) ( 1, 1176) ( 2, 1838)
#        trivial merge - ( 1,  228) ( 3, 1426) - ( 0,  513) ( 1,  228) ( 2,   29) ( 3, 1426)
#        trivial merge - ( 1,  689) ( 3, 3153) - ( 0, 1479) ( 1,  689) ( 3, 3153)
#        trivial merge - ( 1,  237) ( 3, 1454) - ( 0,  545) ( 1,  237) ( 3, 1454)
#        trivial merge - ( 1, 1115) ( 3, 4207) - ( 0, 2093) ( 1, 1115) ( 2, 1740) ( 3, 4207)
#        trivial merge - ( 1,  196) ( 3, 1351) - ( 0,  431) ( 1,  196) ( 2,  584) ( 3, 1351)
#        trivial merge - ( 1,  202) ( 3, 1369) - ( 0,  450) ( 1,  202) ( 3, 1369)
#        trivial merge - ( 1,  402) ( 3, 2157) - ( 0,  966) ( 1,  402) ( 2,  981) ( 3, 2157)
#        trivial merge - ( 1,   48) ( 3, 1067) - ( 0,  141) ( 1,   48) ( 2,  419) ( 3, 1067)
#        trivial merge - ( 1,  584) ( 3, 2940) - ( 0, 1305) ( 1,  584) ( 3, 2940)
#        FOUND INCONSISTENT - ( 0,  632) ( 1,  189) ( 2,  587) ( 3, 1600) ( 3, 1353)
#        FOUND INCONSISTENT - ( 0, 2070) ( 2, 1757) ( 1, 1059) ( 3, 4507) ( 0, 2198) ( 1, 1176) ( 2, 1838) ( 3, 4169)
#        trivial merge - ( 1,   43) ( 3, 1018) - ( 0,   81) ( 1,   43) ( 3, 1018)
#        trivial merge - ( 1, 1146) ( 3, 4352) - ( 0, 2163) ( 1, 1146) ( 2, 1779) ( 3, 4352)
#        trivial merge - ( 1,  290) ( 3, 1676) - ( 0,  668) ( 1,  290) ( 2,  750) ( 3, 1676)
#        FOUND INCONSISTENT - ( 0,  737) ( 1, 1182) ( 3, 1750) ( 3,  346)
#        FOUND INCONSISTENT - ( 0, 2722) ( 1, 1431) ( 2, 1028) ( 3,  904) ( 1, 1402)
#        trivial merge - ( 1,  267) ( 3, 1561) - ( 0,  606) ( 1,  267) ( 3, 1561)
#        trivial merge - ( 1,  131) ( 3, 1233) - ( 0,  320) ( 1,  131) ( 2,  525) ( 3, 1233)
#        trivial merge - ( 1,  111) ( 3, 1169) - ( 0,  244) ( 1,  111) ( 2,   68) ( 3, 1169)
#        trivial merge - ( 1,  395) ( 3, 2233) - ( 0,  979) ( 1,  395) ( 2, 1035) ( 3, 2233)
#        trivial merge - ( 1,    9) ( 3,  989) - ( 0,   65) ( 1,    9) ( 3,  989)
#        trivial merge - ( 1,  623) ( 3, 3027) - ( 0, 1368) ( 1,  623) ( 2, 1331) ( 3, 3027)
#        non-trivial merge - matches ( 1, 1413) ( 3, 4480)
#                            track one ( 0, 2774) ( 1, 1413)
#                            track two ( 0, 2824) ( 3, 4480)
#                            => ( 0, 2824) ( 3, 4480) ( 0, 2774) ( 1, 1413)  - False
#        FOUND INCONSISTENT - ( 0, 2824) ( 3, 4480) ( 0, 2774) ( 1, 1413)
#        trivial merge - ( 1,  114) ( 3, 1231) - ( 0,  297) ( 1,  114) ( 2,  522) ( 3, 1231)
#        trivial merge - ( 1,  236) ( 3, 1434) - ( 0,  531) ( 1,  236) ( 2,  631) ( 3, 1434)
#        trivial merge - ( 1,   44) ( 3, 1077) - ( 0,  153) ( 1,   44) ( 2,  429) ( 3, 1077)
#        trivial merge - ( 1,  469) ( 3, 2590) - ( 0, 1131) ( 1,  469) ( 3, 2590)
#        trivial merge - ( 1,  257) ( 3, 1485) - ( 0,  576) ( 1,  257) ( 2,  671) ( 3, 1485)
#        trivial merge - ( 1,   52) ( 3, 1078) - ( 0,  149) ( 1,   52) ( 3, 1078)
#        trivial merge - ( 1,  137) ( 3, 1265) - ( 0,  332) ( 1,  137) ( 2,  543) ( 3, 1265)
#        trivial merge - ( 1,   61) ( 3, 1110) - ( 0,  181) ( 1,   61) ( 2,  453) ( 3, 1110)
#        trivial merge - ( 1,  104) ( 3, 1165) - ( 0,  245) ( 1,  104) ( 2,  483) ( 3, 1165)
#        trivial merge - ( 1,  266) ( 3, 1535) - ( 0,  589) ( 1,  266) ( 2,  680) ( 3, 1535)
#        FOUND INCONSISTENT - ( 0,  162) ( 1,   77) ( 2,  421) ( 3, 1076) ( 3, 1073)
#        trivial merge - ( 1,  239) ( 3, 1439) - ( 0,  536) ( 1,  239) ( 2,  633) ( 3, 1439)
#        trivial merge - ( 1,  694) ( 3, 3161) - ( 0, 1490) ( 1,  694) ( 2, 1382) ( 2, 1383) ( 3, 3161)
#        trivial merge - ( 1,  468) ( 3, 2589) - ( 0, 1132) ( 1,  468) ( 2,  183) ( 3, 2589)
#        trivial merge - ( 1,  624) ( 3, 3033) - ( 0, 1370) ( 1,  624) ( 3, 3033)
#        trivial merge - ( 1, 1298) ( 3, 4989) - ( 0, 2432) ( 1, 1298) ( 3, 4989)
#        trivial merge - ( 1,  332) ( 3, 1764) - ( 0,  741) ( 1,  332) ( 2,  780) ( 3, 1764)
#        FOUND INCONSISTENT - ( 0, 2493) ( 1, 1331) ( 2, 2053) ( 0, 2406) ( 1, 1287) ( 3, 4948)
#        trivial merge - ( 1,  167) ( 3, 1283) - ( 0,  356) ( 1,  167) ( 2, 1549) ( 3, 1283)
#        trivial merge - ( 1, 1269) ( 3, 4834) - ( 0, 2374) ( 1, 1269) ( 3, 4834)
#        trivial merge - ( 1,  562) ( 3, 2749) - ( 0, 1249) ( 1,  562) ( 2, 1236) ( 2, 1249) ( 3, 2749)
#        trivial merge - ( 1,  184) ( 3, 1286) - ( 0,  365) ( 1,  184) ( 2,  547) ( 3, 1286)
#        trivial merge - ( 1,  213) ( 3, 1368) - ( 0,  461) ( 1,  213) ( 2, 2055) ( 1, 1362) ( 3, 1368)
#        non-trivial merge - matches ( 1,   27) ( 3,  985)
#                            track one ( 0,   32) ( 1,   27) ( 3,  552)
#                            track two ( 0, 1377) ( 3,  985)
#                            => ( 0, 1377) ( 3,  985) ( 0,   32) ( 1,   27) ( 3,  552)  - False
#        FOUND INCONSISTENT - ( 0, 1377) ( 3,  985) ( 0,   32) ( 1,   27) ( 3,  552)
#        non-trivial merge - matches ( 1, 1388) ( 3, 1559)
#                            track one ( 0,  414) ( 1,  209) ( 2,  512) ( 0, 1404) ( 1, 1388)
#                            track two ( 0, 2016) ( 3, 1559)
#                            => ( 0, 2016) ( 3, 1559) ( 0,  414) ( 1,  209) ( 2,  512) ( 0, 1404) ( 1, 1388)  - False
#        FOUND INCONSISTENT - ( 0, 2016) ( 3, 1559) ( 0,  414) ( 1,  209) ( 2,  512) ( 0, 1404) ( 1, 1388)
#        trivial merge - ( 1,  330) ( 3, 1832) - ( 0,  755) ( 1,  330) ( 3, 1832)
#        FOUND INCONSISTENT - ( 0,  339) ( 2,  538) ( 1,  130) ( 3,   85) ( 1,   55)
#        FOUND INCONSISTENT - ( 0, 1454) ( 1,  661) ( 2, 1368) ( 3, 3148) ( 3, 3062)
#        trivial merge - ( 1,  356) ( 3, 1997) - ( 0,  849) ( 1,  356) ( 2,  897) ( 2,  172) ( 3, 1997)
#        trivial merge - ( 1,  271) ( 3, 1544) - ( 0,  600) ( 1,  271) ( 2,  681) ( 3, 1544)
#        trivial merge - ( 1,  355) ( 3, 1992) - ( 0,  847) ( 1,  355) ( 2,  895) ( 3, 1992)
#        non-trivial merge - matches ( 1, 1111) ( 3, 2260)
#                            track one ( 0,    5) ( 1, 1111)
#                            track two ( 0, 2150) ( 3, 2260)
#                            => ( 0, 2150) ( 3, 2260) ( 0,    5) ( 1, 1111)  - False
#        FOUND INCONSISTENT - ( 0, 2150) ( 3, 2260) ( 0,    5) ( 1, 1111)
#        trivial merge - ( 1,  806) ( 3, 3383) - ( 0, 1628) ( 1,  806) ( 3, 3383)
#        FOUND INCONSISTENT - ( 0,   59) ( 1, 1068) ( 3, 3297) ( 1,  785)
#        trivial merge - ( 1, 1126) ( 3, 4249) - ( 0, 2114) ( 1, 1126) ( 3, 4249)
#        non-trivial merge - matches ( 1, 1259) ( 3, 3688)
#                            track one ( 0, 2118) ( 1, 1259)
#                            track two ( 0, 1379) ( 3, 3688)
#                            => ( 0, 1379) ( 3, 3688) ( 0, 2118) ( 1, 1259)  - False
#        FOUND INCONSISTENT - ( 0, 1379) ( 3, 3688) ( 0, 2118) ( 1, 1259)
#        non-trivial merge - matches ( 1,   65) ( 3, 1253)
#                            track one ( 0,  197) ( 1,   65) ( 2,  456)
#                            track two ( 0,  341) ( 3, 1253)
#                            => ( 0,  341) ( 3, 1253) ( 0,  197) ( 1,   65) ( 2,  456)  - False
#        FOUND INCONSISTENT - ( 0,  341) ( 3, 1253) ( 0,  197) ( 1,   65) ( 2,  456)
#        trivial merge - ( 1,  238) ( 3, 1411) - ( 0,  503) ( 1,  238) ( 2,  610) ( 3, 1411)
#        non-trivial merge - matches ( 1,  400) ( 3, 2236)
#                            track one ( 0,  693) ( 1,  400)
#                            track two ( 0,  995) ( 3, 2236)
#                            => ( 0,  995) ( 3, 2236) ( 0,  693) ( 1,  400)  - False
#        FOUND INCONSISTENT - ( 0,  995) ( 3, 2236) ( 0,  693) ( 1,  400)
#        FOUND INCONSISTENT - ( 0, 1464) ( 1,  848) ( 2, 1626) ( 2, 1510) ( 3, 3512)
#        non-trivial merge - matches ( 1,  804) ( 3, 3371)
#                            track one ( 0, 2364) ( 1,  865) ( 2, 1461) ( 0, 2794) ( 1,  804)
#                            track two ( 0, 2753) ( 3, 3371)
#                            => ( 0, 2753) ( 3, 3371) ( 0, 2364) ( 1,  865) ( 2, 1461) ( 0, 2794) ( 1,  804)  - False
#        FOUND INCONSISTENT - ( 0, 2753) ( 3, 3371) ( 0, 2364) ( 1,  865) ( 2, 1461) ( 0, 2794) ( 1,  804)
#        trivial merge - ( 1, 1139) ( 3, 4267) - ( 0, 2135) ( 1, 1139) ( 3, 4267)
#        trivial merge - ( 1,   14) ( 3,  974) - ( 0,   39) ( 1,   14) ( 2,  106) ( 3,  974)
#        trivial merge - ( 1,   75) ( 3, 1122) - ( 0,  204) ( 1,   75) ( 2,  460) ( 3, 1122)
#        non-trivial merge - matches ( 1,  701) ( 3, 3091)
#                            track one ( 1,  701) ( 2, 1990)
#                            track two ( 0, 1482) ( 3, 3091)
#                            => ( 0, 1482) ( 3, 3091) ( 1,  701) ( 2, 1990)  - True
#        trivial merge - ( 1,  628) ( 3, 3054) - ( 0, 1383) ( 1,  628) ( 2,  762) ( 3, 3054)
#        non-trivial merge - matches ( 1,  193) ( 3, 1211)
#                            track one ( 0,  696) ( 1,  193) ( 2,  128)
#                            track two ( 0,  151) ( 3, 1211)
#                            => ( 0,  151) ( 3, 1211) ( 0,  696) ( 1,  193) ( 2,  128)  - False
#        FOUND INCONSISTENT - ( 0,  151) ( 3, 1211) ( 0,  696) ( 1,  193) ( 2,  128)
#        trivial merge - ( 1,   34) ( 3, 1051) - ( 0,  122) ( 1,   34) ( 2,  410) ( 3, 1051)
#        FOUND INCONSISTENT - ( 0, 1649) ( 2,  636) ( 0,  699) ( 1, 1220) ( 3, 3987)
#        trivial merge - ( 1,  132) ( 3, 1204) - ( 0,  268) ( 2,  500) ( 0,  321) ( 1,  132) ( 3, 1204)
#        trivial merge - ( 1,  109) ( 3,  503) - ( 0,  249) ( 1,  109) ( 3,  503)
#        FOUND INCONSISTENT - ( 0,  822) ( 1, 1195) ( 2,  864) ( 2, 1832) ( 3, 1924) ( 3, 4451)
#        trivial merge - ( 1,  412) ( 3, 2188) - ( 0,  988) ( 1,  412) ( 3, 2188)
#        non-trivial merge - matches ( 1,  209) ( 3,  368)
#                            track one ( 0, 2016) ( 3, 1559) ( 0,  414) ( 1,  209) ( 2,  512) ( 0, 1404) ( 1, 1388)
#                            track two ( 0, 2433) ( 3,  368)
#                            => ( 0, 2433) ( 3,  368) ( 0, 2016) ( 3, 1559) ( 0,  414) ( 1,  209) ( 2,  512) ( 0, 1404) ( 1, 1388)  - False
#        FOUND INCONSISTENT - ( 0, 2433) ( 3,  368) ( 0, 2016) ( 3, 1559) ( 0,  414) ( 1,  209) ( 2,  512) ( 0, 1404) ( 1, 1388)
#        trivial merge - ( 1,  157) ( 3, 3949) - ( 0,  400) ( 1,  157) ( 3, 3949)
#        non-trivial merge - matches ( 1, 1165) ( 3,  660)
#                            track one ( 1, 1165) ( 2, 1782)
#                            track two ( 0,  534) ( 3,  660)
#                            => ( 0,  534) ( 3,  660) ( 1, 1165) ( 2, 1782)  - True
#        trivial merge - ( 1,   97) ( 3, 1161) - ( 0,  250) ( 1,   97) ( 2,  476) ( 3, 1161)
#        trivial merge - ( 1,  516) ( 3, 1432) - ( 0, 1214) ( 1,  516) ( 3, 1432)
#        non-trivial merge - matches ( 1, 1421) ( 3, 2189)
#                            track one ( 0, 2112) ( 1, 1421) ( 2,  997) ( 3, 3301)
#                            track two ( 0, 1440) ( 3, 2189)
#                            => ( 0, 1440) ( 3, 2189) ( 0, 2112) ( 1, 1421) ( 2,  997) ( 3, 3301)  - False
#        FOUND INCONSISTENT - ( 0, 1440) ( 3, 2189) ( 0, 2112) ( 1, 1421) ( 2,  997) ( 3, 3301)
#   144 tracks created
#    18 tracks in C extended with point in B
#   107 tracks in B extended with point in C
#   110 tracks merged (trivial)
#   110 tracks merged (non-trivial)
#    43 inconsistent tracks
#
# matching image 2 with image 3 with threshold 0.9:
#   593 good matches found
#        non-trivial merge - matches ( 2, 1770) ( 3, 4339)
#                            track one ( 0, 2149) ( 1, 1141) ( 2, 1770) ( 3, 4328)
#                            track two ( 0, 2169) ( 1, 1153) ( 3, 4339)
#                            => ( 0, 2169) ( 1, 1153) ( 3, 4339) ( 0, 2149) ( 1, 1141) ( 2, 1770) ( 3, 4328)  - False
#        FOUND INCONSISTENT - ( 0, 2169) ( 1, 1153) ( 3, 4339) ( 0, 2149) ( 1, 1141) ( 2, 1770) ( 3, 4328)
#        trivial merge - ( 2,  610) ( 3, 1411) - ( 0,  503) ( 1,  238) ( 2,  610) ( 3, 1411)
#        trivial merge - ( 2,  737) ( 3, 1649) - ( 1,  299) ( 2,  737) ( 3, 1649)
#        trivial merge - ( 2,  760) ( 3, 1723) - ( 1,  321) ( 2,  760) ( 3, 1723)
#        trivial merge - ( 2,  454) ( 3, 1118) - ( 0,  200) ( 1,   93) ( 2,  454) ( 3, 1118)
#        trivial merge - ( 2, 1347) ( 3, 3073) - ( 0, 1448) ( 1,  674) ( 2, 1347) ( 3, 3073)
#        trivial merge - ( 2, 1684) ( 3, 4078) - ( 1, 1048) ( 2, 1684) ( 3, 4078)
#        trivial merge - ( 2,  801) ( 3, 1815) - ( 0,  753) ( 1,  335) ( 2,  801) ( 3, 1815)
#        trivial merge - ( 2,  421) ( 3, 1073) - ( 0,  162) ( 1,   77) ( 2,  421) ( 3, 1076) ( 3, 1073)
#        trivial merge - ( 2, 1382) ( 3, 3161) - ( 0, 1490) ( 1,  694) ( 2, 1382) ( 2, 1383) ( 3, 3161)
#        trivial merge - ( 2,  519) ( 3, 1223) - ( 0,  284) ( 1,  106) ( 2,  519) ( 3, 1223)
#        trivial merge - ( 2,  460) ( 3, 1122) - ( 0,  204) ( 1,   75) ( 2,  460) ( 3, 1122)
#        FOUND INCONSISTENT - ( 1, 1373) ( 2, 2080) ( 3,  882) ( 2,  336)
#        trivial merge - ( 2,  686) ( 3, 1553) - ( 0,  609) ( 1,  286) ( 2,  686) ( 3, 1553)
#        trivial merge - ( 2,  455) ( 3, 1119) - ( 0,  201) ( 1,   94) ( 2,  455) ( 3, 1119)
#        trivial merge - ( 2,  525) ( 3, 1233) - ( 0,  320) ( 1,  131) ( 2,  525) ( 3, 1233)
#        FOUND INCONSISTENT - ( 0,  260) ( 1,  128) ( 2,  174) ( 3, 1183) ( 3,  635)
#        trivial merge - ( 2,  849) ( 3, 1882) - ( 0,  773) ( 2,  849) ( 3, 1882)
#        trivial merge - ( 2, 1481) ( 3, 3400) - ( 0, 1633) ( 1,  802) ( 2, 1481) ( 3, 3400)
#        trivial merge - ( 2,  665) ( 3, 1484) - ( 0,  565) ( 2,  665) ( 3, 1484)
#        trivial merge - ( 2, 1219) ( 3, 2699) - ( 0, 1177) ( 1,  498) ( 2, 1219) ( 3, 2699)
#        trivial merge - ( 2,  680) ( 3, 1535) - ( 0,  589) ( 1,  266) ( 2,  680) ( 3, 1535)
#        trivial merge - ( 2, 1921) ( 3, 4811) - ( 0, 2367) ( 1, 1263) ( 2, 1921) ( 3, 4811)
#        trivial merge - ( 2, 1731) ( 3, 4202) - ( 0, 2083) ( 1, 1110) ( 2, 1731) ( 3, 4202)
#        trivial merge - ( 2,  506) ( 3, 1201) - ( 0,  271) ( 1,  101) ( 2,  506) ( 3, 1201)
#        trivial merge - ( 2,  410) ( 3, 1051) - ( 0,  122) ( 1,   34) ( 2,  410) ( 3, 1051)
#        trivial merge - ( 2,  476) ( 3, 1161) - ( 0,  250) ( 1,   97) ( 2,  476) ( 3, 1161)
#        FOUND INCONSISTENT - ( 0, 1383) ( 1,  628) ( 2,  762) ( 3, 3054) ( 3, 1735)
#        trivial merge - ( 2, 1220) ( 3, 2700) - ( 1,  499) ( 2, 1220) ( 3, 2700)
#        trivial merge - ( 2,  747) ( 3, 1671) - ( 0,  676) ( 1,  494) ( 2,  747) ( 3, 1671)
#        trivial merge - ( 2, 1778) ( 3, 4351) - ( 0, 2162) ( 1, 1145) ( 2, 1778) ( 3, 4351)
#        non-trivial merge - matches ( 2,  332) ( 3,  867)
#                            track one ( 1,   38) ( 2,  332) ( 3, 1039)
#                            track two ( 0,  159) ( 3,  867)
#                            => ( 0,  159) ( 3,  867) ( 1,   38) ( 2,  332) ( 3, 1039)  - False
#        FOUND INCONSISTENT - ( 0,  159) ( 3,  867) ( 1,   38) ( 2,  332) ( 3, 1039)
#        trivial merge - ( 2, 1869) ( 3, 4642) - ( 0, 2321) ( 1, 1248) ( 2, 1869) ( 3, 4642)
#        trivial merge - ( 2, 1181) ( 3, 2604) - ( 0, 1137) ( 1,  471) ( 2, 1181) ( 3, 2604)
#        trivial merge - ( 2,  543) ( 3, 1265) - ( 0,  332) ( 1,  137) ( 2,  543) ( 3, 1265)
#        trivial merge - ( 2,  623) ( 3, 1433) - ( 0,  538) ( 1,  243) ( 2,  623) ( 3, 1433)
#        trivial merge - ( 2,  884) ( 3, 1970) - ( 0,  856) ( 1,  370) ( 2,  884) ( 3, 1970)
#        trivial merge - ( 2,  523) ( 3,  890) - ( 0,   34) ( 1,   10) ( 2,  523) ( 1,   96) ( 3,  890)
#        trivial merge - ( 2, 1342) ( 3, 3051) - ( 1,  662) ( 2, 1342) ( 3, 3051)
#        trivial merge - ( 2,  380) ( 3,  983) - ( 0,   41) ( 2,  380) ( 3,  983)
#        trivial merge - ( 2,  963) ( 3, 2119) - ( 0,  918) ( 1,  380) ( 2,  963) ( 3, 2119)
#        trivial merge - ( 2, 1236) ( 3, 2749) - ( 0, 1249) ( 1,  562) ( 2, 1236) ( 2, 1249) ( 3, 2749)
#        trivial merge - ( 2, 1189) ( 3, 2630) - ( 0, 1192) ( 1,  525) ( 2, 1189) ( 3, 2630)
#        trivial merge - ( 2,  611) ( 3, 1409) - ( 1,  207) ( 2,  611) ( 3, 1409)
#        trivial merge - ( 2,  416) ( 3, 1056) - ( 0,  129) ( 1,   37) ( 2,  416) ( 3, 1056)
#        trivial merge - ( 2, 1176) ( 3, 2603) - ( 1,  519) ( 2, 1176) ( 3, 2603)
#        trivial merge - ( 2,  679) ( 3, 1512) - ( 0,  572) ( 1,  247) ( 2,  679) ( 3, 1512)
#        trivial merge - ( 2,  926) ( 3, 2063) - ( 0,  909) ( 2,  926) ( 1,  318) ( 3, 2063) ( 1,  389)
#        trivial merge - ( 2,  890) ( 3, 1922) - ( 0,  823) ( 1,  358) ( 2,  444) ( 2,  890) ( 1,   89) ( 3, 1922)
#        trivial merge - ( 2, 1072) ( 3, 2327) - ( 1,  451) ( 2, 1072) ( 3, 2327)
#        non-trivial merge - matches ( 2, 1934) ( 3, 5061)
#                            track one ( 0, 1803) ( 1,  989) ( 2, 1934)
#                            track two ( 0, 2256) ( 3, 5061)
#                            => ( 0, 2256) ( 3, 5061) ( 0, 1803) ( 1,  989) ( 2, 1934)  - False
#        FOUND INCONSISTENT - ( 0, 2256) ( 3, 5061) ( 0, 1803) ( 1,  989) ( 2, 1934)
#        trivial merge - ( 2, 1115) ( 3, 2424) - ( 0, 1065) ( 1,  430) ( 2, 1115) ( 3, 2424)
#        trivial merge - ( 2, 1439) ( 3, 3269) - ( 1,  739) ( 2, 1439) ( 3, 3269)
#        trivial merge - ( 2, 1284) ( 3, 2872) - ( 1,  598) ( 2, 1284) ( 3, 2872)
#        non-trivial merge - matches ( 2, 1803) ( 3, 4403)
#                            track one ( 1,   56) ( 2, 1803)
#                            track two ( 0, 2140) ( 1, 1133) ( 3, 4403)
#                            => ( 0, 2140) ( 1, 1133) ( 3, 4403) ( 1,   56) ( 2, 1803)  - False
#        FOUND INCONSISTENT - ( 0, 2140) ( 1, 1133) ( 3, 4403) ( 1,   56) ( 2, 1803)
#        trivial merge - ( 2, 1800) ( 3, 4421) - ( 0, 2203) ( 1, 1174) ( 2, 1800) ( 3, 4421)
#        trivial merge - ( 2,  750) ( 3, 1676) - ( 0,  668) ( 1,  290) ( 2,  750) ( 3, 1676)
#        trivial merge - ( 2,  607) ( 3, 1412) - ( 0,  570) ( 1,  222) ( 2,   13) ( 2,  607) ( 3, 1412)
#        trivial merge - ( 2, 1643) ( 3, 3927) - ( 0, 1862) ( 1,  960) ( 2, 1643) ( 3, 3927)
#        trivial merge - ( 2,  419) ( 3, 1067) - ( 0,  141) ( 1,   48) ( 2,  419) ( 3, 1067)
#        trivial merge - ( 2, 1348) ( 3, 3090) - ( 1,  708) ( 2, 1348) ( 3, 3090)
#        trivial merge - ( 2,  448) ( 3, 1102) - ( 0,  177) ( 1,   62) ( 2,  448) ( 3, 1102)
#        FOUND INCONSISTENT - ( 0,  894) ( 1,  381) ( 2,  646) ( 1,  107) ( 3, 1154) ( 3, 1029) ( 2,  560)
#        trivial merge - ( 2,  962) ( 3, 2118) - ( 0,  917) ( 2,  962) ( 3, 2118)
#        non-trivial merge - matches ( 2,  148) ( 3,  585)
#                            track one ( 0, 1537) ( 2,  148)
#                            track two ( 0, 1589) ( 3,  585)
#                            => ( 0, 1589) ( 3,  585) ( 0, 1537) ( 2,  148)  - False
#        FOUND INCONSISTENT - ( 0, 1589) ( 3,  585) ( 0, 1537) ( 2,  148)
#        trivial merge - ( 2, 1913) ( 3, 4789) - ( 0, 2385) ( 1, 1275) ( 2, 1913) ( 3, 4789)
#        trivial merge - ( 2, 1362) ( 3, 3083) - ( 0, 1457) ( 1,  682) ( 2, 1362) ( 3, 3083)
#        trivial merge - ( 2, 1706) ( 3, 4143) - ( 0, 2046) ( 1, 1082) ( 2, 1706) ( 3, 4143)
#        trivial merge - ( 2,  549) ( 3, 1291) - ( 0,  345) ( 1,  153) ( 2,  549) ( 3, 1291)
#        trivial merge - ( 2,  453) ( 3, 1110) - ( 0,  181) ( 1,   61) ( 2,  453) ( 3, 1110)
#        trivial merge - ( 2,  633) ( 3, 1439) - ( 0,  536) ( 1,  239) ( 2,  633) ( 3, 1439)
#        non-trivial merge - matches ( 2, 1404) ( 3, 3182)
#                            track one ( 0, 1468) ( 1,  670) ( 2, 1404) ( 3, 3201)
#                            track two ( 1,  641) ( 2, 1366) ( 3, 3182)
#                            => ( 1,  641) ( 2, 1366) ( 3, 3182) ( 0, 1468) ( 1,  670) ( 2, 1404) ( 3, 3201)  - False
#        FOUND INCONSISTENT - ( 1,  641) ( 2, 1366) ( 3, 3182) ( 0, 1468) ( 1,  670) ( 2, 1404) ( 3, 3201)
#        trivial merge - ( 2,  593) ( 3, 1361) - ( 1,  203) ( 2,  593) ( 3, 1361)
#        trivial merge - ( 2,  522) ( 3, 1231) - ( 0,  297) ( 1,  114) ( 2,  522) ( 3, 1231)
#        non-trivial merge - matches ( 2, 1639) ( 3, 4832)
#                            track one ( 0, 2370) ( 2, 1639) ( 1, 1406)
#                            track two ( 0, 1969) ( 3, 4832) ( 0, 2410) ( 1, 1448)
#                            => ( 0, 1969) ( 3, 4832) ( 0, 2410) ( 1, 1448) ( 0, 2370) ( 2, 1639) ( 1, 1406)  - False
#        FOUND INCONSISTENT - ( 0, 1969) ( 3, 4832) ( 0, 2410) ( 1, 1448) ( 0, 2370) ( 2, 1639) ( 1, 1406)
#        trivial merge - ( 2,  404) ( 3, 1021) - ( 0,  100) ( 1,   28) ( 2,  404) ( 3, 1021)
#        non-trivial merge - matches ( 2, 2108) ( 3, 3452)
#                            track one ( 0, 1818) ( 2, 2108)
#                            track two ( 0, 2103) ( 1, 1036) ( 3, 3452) ( 3, 4109)
#                            => ( 0, 2103) ( 1, 1036) ( 3, 3452) ( 3, 4109) ( 0, 1818) ( 2, 2108)  - False
#        FOUND INCONSISTENT - ( 0, 2103) ( 1, 1036) ( 3, 3452) ( 3, 4109) ( 0, 1818) ( 2, 2108)
#        trivial merge - ( 2, 1321) ( 3, 2995) - ( 0, 1344) ( 1,  611) ( 2, 1321) ( 3, 2995)
#        FOUND INCONSISTENT - ( 0, 2343) ( 3, 4690) ( 0, 2516) ( 1, 1297) ( 2, 2016) ( 2,  898)
#        non-trivial merge - matches ( 2,  238) ( 3,  723)
#                            track one ( 0, 1034) ( 2,  238)
#                            track two ( 0,  714) ( 1,  331) ( 3,  723)
#                            => ( 0,  714) ( 1,  331) ( 3,  723) ( 0, 1034) ( 2,  238)  - False
#        FOUND INCONSISTENT - ( 0,  714) ( 1,  331) ( 3,  723) ( 0, 1034) ( 2,  238)
#        trivial merge - ( 2,  605) ( 3, 1390) - ( 0,  488) ( 1,  212) ( 2,  605) ( 3, 1390)
#        trivial merge - ( 2,  587) ( 3, 1353) - ( 0,  632) ( 1,  189) ( 2,  587) ( 3, 1600) ( 3, 1353)
#        trivial merge - ( 2,  667) ( 3, 1479) - ( 0,  563) ( 2,  667) ( 3, 1479)
#        trivial merge - ( 2,  780) ( 3, 1764) - ( 0,  741) ( 1,  332) ( 2,  780) ( 3, 1764)
#        trivial merge - ( 2, 1378) ( 3, 3147) - ( 1,  688) ( 2, 1378) ( 3, 3147)
#        trivial merge - ( 2,  547) ( 3, 1286) - ( 0,  365) ( 1,  184) ( 2,  547) ( 3, 1286)
#        trivial merge - ( 2, 1331) ( 3, 3027) - ( 0, 1368) ( 1,  623) ( 2, 1331) ( 3, 3027)
#        non-trivial merge - matches ( 2,  727) ( 3, 1413)
#                            track one ( 0,  573) ( 1,  269) ( 2,  727)
#                            track two ( 0,  506) ( 1,  245) ( 2,  292) ( 3, 1416) ( 3, 1413)
#                            => ( 0,  506) ( 1,  245) ( 2,  292) ( 3, 1416) ( 3, 1413) ( 0,  573) ( 1,  269) ( 2,  727)  - False
#        FOUND INCONSISTENT - ( 0,  506) ( 1,  245) ( 2,  292) ( 3, 1416) ( 3, 1413) ( 0,  573) ( 1,  269) ( 2,  727)
#        non-trivial merge - matches ( 2,  487) ( 3,  402)
#                            track one ( 1,  339) ( 2,  487)
#                            track two ( 1,  457) ( 3,  402)
#                            => ( 1,  457) ( 3,  402) ( 1,  339) ( 2,  487)  - False
#        FOUND INCONSISTENT - ( 1,  457) ( 3,  402) ( 1,  339) ( 2,  487)
#        non-trivial merge - matches ( 2, 1927) ( 3, 4817)
#                            track one ( 0,  973) ( 2, 1927) ( 0, 2142) ( 1, 1135)
#                            track two ( 0, 2366) ( 3, 4817) ( 1, 1264)
#                            => ( 0, 2366) ( 3, 4817) ( 1, 1264) ( 0,  973) ( 2, 1927) ( 0, 2142) ( 1, 1135)  - False
#        FOUND INCONSISTENT - ( 0, 2366) ( 3, 4817) ( 1, 1264) ( 0,  973) ( 2, 1927) ( 0, 2142) ( 1, 1135)
#        FOUND INCONSISTENT - ( 0, 1588) ( 2,   36) ( 0, 1546) ( 1,  710) ( 3, 1527) ( 3,  422)
#        non-trivial merge - matches ( 2, 1485) ( 3, 4528)
#                            track one ( 0, 2065) ( 2, 1485) ( 1, 1399)
#                            track two ( 0, 2036) ( 1, 1385) ( 3, 4528) ( 1,  799)
#                            => ( 0, 2036) ( 1, 1385) ( 3, 4528) ( 1,  799) ( 0, 2065) ( 2, 1485) ( 1, 1399)  - False
#        FOUND INCONSISTENT - ( 0, 2036) ( 1, 1385) ( 3, 4528) ( 1,  799) ( 0, 2065) ( 2, 1485) ( 1, 1399)
#        trivial merge - ( 2,  517) ( 3, 1230) - ( 0,  306) ( 1,  156) ( 2,  517) ( 3, 1230)
#        trivial merge - ( 2,  598) ( 3, 1376) - ( 0,  451) ( 1,  200) ( 2,  598) ( 3, 1376)
#        trivial merge - ( 2, 1392) ( 3, 3158) - ( 0,  164) ( 2, 1392) ( 1,  654) ( 3, 3158)
#        non-trivial merge - matches ( 2,  420) ( 3, 1828)
#                            track one ( 1,   70) ( 2,  420)
#                            track two ( 0,  774) ( 2,  794) ( 3, 1828)
#                            => ( 0,  774) ( 2,  794) ( 3, 1828) ( 1,   70) ( 2,  420)  - False
#        FOUND INCONSISTENT - ( 0,  774) ( 2,  794) ( 3, 1828) ( 1,   70) ( 2,  420)
#        trivial merge - ( 2,  799) ( 3, 1803) - ( 0,  752) ( 1,  336) ( 2,  799) ( 3, 1803)
#        trivial merge - ( 2,  677) ( 3, 1508) - ( 0,  681) ( 2,  677) ( 1,  252) ( 3, 1508)
#        trivial merge - ( 2, 1393) ( 3, 3159) - ( 0, 1439) ( 3, 3159) ( 1,  655) ( 2, 1393)
#        trivial merge - ( 2, 1323) ( 3, 3005) - ( 0, 1407) ( 1,  650) ( 2, 1323) ( 3, 3005)
#        trivial merge - ( 2, 1447) ( 3, 3280) - ( 0, 1563) ( 1,  845) ( 2, 1447) ( 2, 1558) ( 3, 3280)
#        trivial merge - ( 2,  707) ( 3, 1607) - ( 0,  640) ( 1,  296) ( 2,  707) ( 3, 1607)
#        trivial merge - ( 2,  429) ( 3, 1077) - ( 0,  153) ( 1,   44) ( 2,  429) ( 3, 1077)
#        non-trivial merge - matches ( 2,  888) ( 3, 1978)
#                            track one ( 0, 1040) ( 1, 1314) ( 2,  888)
#                            track two ( 0,  858) ( 3, 1978)
#                            => ( 0,  858) ( 3, 1978) ( 0, 1040) ( 1, 1314) ( 2,  888)  - False
#        FOUND INCONSISTENT - ( 0,  858) ( 3, 1978) ( 0, 1040) ( 1, 1314) ( 2,  888)
#        trivial merge - ( 2,  966) ( 3, 2116) - ( 0,  919) ( 1,  371) ( 2,  966) ( 3, 2116)
#        trivial merge - ( 2,  500) ( 3, 1204) - ( 0,  268) ( 2,  500) ( 0,  321) ( 1,  132) ( 3, 1204)
#        trivial merge - ( 2,  676) ( 3, 1507) - ( 0,  577) ( 1,  251) ( 2,  676) ( 3, 1507)
#        trivial merge - ( 2, 1443) ( 3, 4357) - ( 0, 2651) ( 3, 4357) ( 0, 1511) ( 2, 1443) ( 0, 2646) ( 1, 1114)
#        FOUND INCONSISTENT - ( 0,  530) ( 3,   70) ( 0,  529) ( 1,  300) ( 2, 1857)
#        trivial merge - ( 2,  631) ( 3, 1434) - ( 0,  531) ( 1,  236) ( 2,  631) ( 3, 1434)
#        trivial merge - ( 2, 1446) ( 3, 3279) - ( 0, 1562) ( 2, 1446) ( 3, 3279)
#        FOUND INCONSISTENT - ( 0,  822) ( 1, 1195) ( 2,  864) ( 2, 1832) ( 3, 1924) ( 3, 4451) ( 2, 1813)
#        trivial merge - ( 2,  573) ( 3, 1320) - ( 0,  399) ( 1,  174) ( 2,  573) ( 3, 1320)
#        FOUND INCONSISTENT - ( 1,  241) ( 2,  190) ( 3,  649) ( 3,  666)
#        trivial merge - ( 2, 1740) ( 3, 4207) - ( 0, 2093) ( 1, 1115) ( 2, 1740) ( 3, 4207)
#        non-trivial merge - matches ( 2, 1265) ( 3, 2825)
#                            track one ( 0, 1246) ( 2, 1265)
#                            track two ( 0, 1250) ( 3, 2825) ( 1,  175)
#                            => ( 0, 1250) ( 3, 2825) ( 1,  175) ( 0, 1246) ( 2, 1265)  - False
#        FOUND INCONSISTENT - ( 0, 1250) ( 3, 2825) ( 1,  175) ( 0, 1246) ( 2, 1265)
#        FOUND INCONSISTENT - ( 0, 1606) ( 2,   85) ( 3,  694) ( 2,  211)
#        trivial merge - ( 2,  483) ( 3, 1165) - ( 0,  245) ( 1,  104) ( 2,  483) ( 3, 1165)
#        trivial merge - ( 2,  501) ( 3, 1199) - ( 1,  123) ( 2,  501) ( 3, 1199)
#        trivial merge - ( 2, 1779) ( 3, 4352) - ( 0, 2163) ( 1, 1146) ( 2, 1779) ( 3, 4352)
#        trivial merge - ( 2, 1035) ( 3, 2233) - ( 0,  979) ( 1,  395) ( 2, 1035) ( 3, 2233)
#        trivial merge - ( 2,  557) ( 3, 1298) - ( 0,  360) ( 2,  557) ( 1,  180) ( 3, 1298)
#        FOUND INCONSISTENT - ( 0,  390) ( 3, 1046) ( 0,  324) ( 1,  116) ( 2,  418)
#        FOUND INCONSISTENT - ( 0, 1466) ( 2, 1435) ( 3, 2053) ( 2,  920)
#        trivial merge - ( 2, 1092) ( 3, 2363) - ( 0, 1047) ( 1,  416) ( 2, 1092) ( 3, 2363)
#        non-trivial merge - matches ( 2, 1838) ( 3, 5047)
#                            track one ( 0, 2070) ( 2, 1757) ( 1, 1059) ( 3, 4507) ( 0, 2198) ( 1, 1176) ( 2, 1838) ( 3, 4169)
#                            track two ( 0, 2449) ( 3, 5047)
#                            => ( 0, 2449) ( 3, 5047) ( 0, 2070) ( 2, 1757) ( 1, 1059) ( 3, 4507) ( 0, 2198) ( 1, 1176) ( 2, 1838) ( 3, 4169)  - False
#        FOUND INCONSISTENT - ( 0, 2449) ( 3, 5047) ( 0, 2070) ( 2, 1757) ( 1, 1059) ( 3, 4507) ( 0, 2198) ( 1, 1176) ( 2, 1838) ( 3, 4169)
#        FOUND INCONSISTENT - ( 0, 2721) ( 1,  197) ( 2,  102) ( 3,  538) ( 3, 2881) ( 2,  163)
#        trivial merge - ( 2,  671) ( 3, 1485) - ( 0,  576) ( 1,  257) ( 2,  671) ( 3, 1485)
#        trivial merge - ( 2,  527) ( 3, 1236) - ( 0,  316) ( 1,  154) ( 2,  527) ( 3, 1236)
#        trivial merge - ( 2,  681) ( 3, 1544) - ( 0,  600) ( 1,  271) ( 2,  681) ( 3, 1544)
#        trivial merge - ( 2, 1190) ( 3, 2626) - ( 0, 1145) ( 1,  482) ( 2, 1190) ( 3, 2626)
#        FOUND INCONSISTENT - ( 0, 2378) ( 2, 1805) ( 0, 2171) ( 1, 1426) ( 3, 4273)
#        trivial merge - ( 2,  873) ( 3, 1951) - ( 0,  830) ( 2,  873) ( 3, 1951)
#        trivial merge - ( 2,  613) ( 3, 1414) - ( 0,  496) ( 2,  613) ( 3, 1414)
#        non-trivial merge - matches ( 2, 1539) ( 3, 4834)
#                            track one ( 1,  820) ( 2, 1539)
#                            track two ( 0, 2374) ( 1, 1269) ( 3, 4834)
#                            => ( 0, 2374) ( 1, 1269) ( 3, 4834) ( 1,  820) ( 2, 1539)  - False
#        FOUND INCONSISTENT - ( 0, 2374) ( 1, 1269) ( 3, 4834) ( 1,  820) ( 2, 1539)
#        trivial merge - ( 2,  895) ( 3, 1992) - ( 0,  847) ( 1,  355) ( 2,  895) ( 3, 1992)
#        non-trivial merge - matches ( 2, 1206) ( 3, 2698)
#                            track one ( 0,  526) ( 2, 1206) ( 1, 1382)
#                            track two ( 1,  571) ( 3, 2698)
#                            => ( 1,  571) ( 3, 2698) ( 0,  526) ( 2, 1206) ( 1, 1382)  - False
#        FOUND INCONSISTENT - ( 1,  571) ( 3, 2698) ( 0,  526) ( 2, 1206) ( 1, 1382)
#        trivial merge - ( 2, 1022) ( 3, 2244) - ( 1,  453) ( 2, 1022) ( 3, 2244)
#        non-trivial merge - matches ( 2, 2043) ( 3, 4217)
#                            track one ( 0, 2502) ( 2, 2043)
#                            track two ( 0, 1896) ( 3, 4217)
#                            => ( 0, 1896) ( 3, 4217) ( 0, 2502) ( 2, 2043)  - False
#        FOUND INCONSISTENT - ( 0, 1896) ( 3, 4217) ( 0, 2502) ( 2, 2043)
#        trivial merge - ( 2, 1207) ( 3, 2708) - ( 0, 1910) ( 1,  578) ( 2, 1207) ( 3, 2708)
#        non-trivial merge - matches ( 2,   86) ( 3,  503)
#                            track one ( 0, 1766) ( 2,   86)
#                            track two ( 0,  249) ( 1,  109) ( 3,  503)
#                            => ( 0,  249) ( 1,  109) ( 3,  503) ( 0, 1766) ( 2,   86)  - False
#        FOUND INCONSISTENT - ( 0,  249) ( 1,  109) ( 3,  503) ( 0, 1766) ( 2,   86)
#        trivial merge - ( 2,  864) ( 3, 1924) - ( 0,  822) ( 1, 1195) ( 2,  864) ( 2, 1832) ( 3, 1924) ( 3, 4451) ( 2, 1813)
#        trivial merge - ( 2, 1461) ( 3, 3371) - ( 0, 2753) ( 3, 3371) ( 0, 2364) ( 1,  865) ( 2, 1461) ( 0, 2794) ( 1,  804)
#        FOUND INCONSISTENT - ( 1,  306) ( 2,  335) ( 3, 4043) ( 2, 1677)
#        trivial merge - ( 2,  782) ( 3, 1768) - ( 0,  738) ( 2,  782) ( 3, 1768)
#        trivial merge - ( 2, 1451) ( 3, 3344) - ( 1,  796) ( 2, 1451) ( 3, 3344)
#        trivial merge - ( 2,  768) ( 3,  879) - ( 0,  722) ( 2,  768) ( 3,  879)
#        non-trivial merge - matches ( 2,   33) ( 3, 3297)
#                            track one ( 0, 1008) ( 2,   33) ( 3,  562)
#                            track two ( 0,   59) ( 1, 1068) ( 3, 3297) ( 1,  785)
#                            => ( 0,   59) ( 1, 1068) ( 3, 3297) ( 1,  785) ( 0, 1008) ( 2,   33) ( 3,  562)  - False
#        FOUND INCONSISTENT - ( 0,   59) ( 1, 1068) ( 3, 3297) ( 1,  785) ( 0, 1008) ( 2,   33) ( 3,  562)
#        FOUND INCONSISTENT - ( 1,  602) ( 2, 1234) ( 3, 2432) ( 2, 1107)
#        trivial merge - ( 2,  584) ( 3, 1351) - ( 0,  431) ( 1,  196) ( 2,  584) ( 3, 1351)
#        FOUND INCONSISTENT - ( 1, 1155) ( 2, 2119) ( 3, 4342) ( 2, 1767)
#        trivial merge - ( 2, 1510) ( 3, 3512) - ( 0, 1464) ( 1,  848) ( 2, 1626) ( 2, 1510) ( 3, 3512)
#        trivial merge - ( 2,   11) ( 3,  906) - ( 0, 2717) ( 2,   11) ( 3,  906)
#        trivial merge - ( 2,  857) ( 3, 1910) - ( 0,  809) ( 2,  857) ( 1,  351) ( 3, 1910)
#        trivial merge - ( 2, 1568) ( 3, 3690) - ( 1,  921) ( 2, 1568) ( 3, 3690)
#        FOUND INCONSISTENT - ( 1,  678) ( 2, 1416) ( 3, 3222) ( 2, 1427)
#        FOUND INCONSISTENT - ( 1,  793) ( 2, 1450) ( 3,  414) ( 3, 3337)
#        trivial merge - ( 2,  897) ( 3, 1997) - ( 0,  849) ( 1,  356) ( 2,  897) ( 2,  172) ( 3, 1997)
#        non-trivial merge - matches ( 2, 1587) ( 3, 3781)
#                            track one ( 0, 1300) ( 1,  608) ( 2, 1587)
#                            track two ( 0, 1731) ( 3, 3781)
#                            => ( 0, 1731) ( 3, 3781) ( 0, 1300) ( 1,  608) ( 2, 1587)  - False
#        FOUND INCONSISTENT - ( 0, 1731) ( 3, 3781) ( 0, 1300) ( 1,  608) ( 2, 1587)
#        trivial merge - ( 2, 1673) ( 3, 4049) - ( 1, 1053) ( 2, 1673) ( 3, 4049)
#        non-trivial merge - matches ( 2, 1200) ( 3, 2676)
#                            track one ( 1,  782) ( 2, 1200)
#                            track two ( 1,  570) ( 3, 2676)
#                            => ( 1,  570) ( 3, 2676) ( 1,  782) ( 2, 1200)  - False
#        FOUND INCONSISTENT - ( 1,  570) ( 3, 2676) ( 1,  782) ( 2, 1200)
#        trivial merge - ( 2, 1672) ( 3, 4048) - ( 1, 1052) ( 2, 1672) ( 3, 4048)
#        trivial merge - ( 2, 2002) ( 3, 2047) - ( 0, 1480) ( 2, 2002) ( 1, 1177) ( 3, 2047)
#        non-trivial merge - matches ( 2,  981) ( 3, 1184)
#                            track one ( 0,  966) ( 1,  402) ( 2,  981) ( 3, 2157)
#                            track two ( 0,  259) ( 3, 1184)
#                            => ( 0,  259) ( 3, 1184) ( 0,  966) ( 1,  402) ( 2,  981) ( 3, 2157)  - False
#        FOUND INCONSISTENT - ( 0,  259) ( 3, 1184) ( 0,  966) ( 1,  402) ( 2,  981) ( 3, 2157)
#        FOUND INCONSISTENT - ( 0,  269) ( 1,  757) ( 2, 1398) ( 3, 2304) ( 3, 3217)
#        FOUND INCONSISTENT - ( 1, 1232) ( 2,  902) ( 3, 4592) ( 3, 2044)
#        FOUND INCONSISTENT - ( 1,  686) ( 2, 1229) ( 3, 3032) ( 3, 2767)
#        trivial merge - ( 2, 1798) ( 3, 4460) - ( 0, 2180) ( 1, 1184) ( 2, 1798) ( 3, 4460)
#        trivial merge - ( 2,  674) ( 3, 1501) - ( 1,  261) ( 2,  674) ( 3, 1501)
#        trivial merge - ( 2, 1888) ( 3, 3322) - ( 1,  788) ( 2, 1888) ( 3, 3322)
#        non-trivial merge - matches ( 2,  168) ( 3, 2953)
#                            track one ( 0,  652) ( 2,  168) ( 3, 3402)
#                            track two ( 0, 1240) ( 1,  652) ( 3, 2953)
#                            => ( 0, 1240) ( 1,  652) ( 3, 2953) ( 0,  652) ( 2,  168) ( 3, 3402)  - False
#        FOUND INCONSISTENT - ( 0, 1240) ( 1,  652) ( 3, 2953) ( 0,  652) ( 2,  168) ( 3, 3402)
#        trivial merge - ( 2,  648) ( 3, 2152) - ( 1,  429) ( 2,  648) ( 3, 2152)
#        non-trivial merge - matches ( 2, 1250) ( 3, 3686)
#                            track one ( 1,  738) ( 2, 1250)
#                            track two ( 1,  916) ( 3, 3686)
#                            => ( 1,  916) ( 3, 3686) ( 1,  738) ( 2, 1250)  - False
#        FOUND INCONSISTENT - ( 1,  916) ( 3, 3686) ( 1,  738) ( 2, 1250)
#        FOUND INCONSISTENT - ( 0, 1482) ( 3, 3091) ( 1,  701) ( 2, 1990) ( 3, 3964)
#        non-trivial merge - matches ( 2,  552) ( 3, 2189)
#                            track one ( 0, 1937) ( 2,  552) ( 3, 3697)
#                            track two ( 0, 1440) ( 3, 2189) ( 0, 2112) ( 1, 1421) ( 2,  997) ( 3, 3301)
#                            => ( 0, 1440) ( 3, 2189) ( 0, 2112) ( 1, 1421) ( 2,  997) ( 3, 3301) ( 0, 1937) ( 2,  552) ( 3, 3697)  - False
#        FOUND INCONSISTENT - ( 0, 1440) ( 3, 2189) ( 0, 2112) ( 1, 1421) ( 2,  997) ( 3, 3301) ( 0, 1937) ( 2,  552) ( 3, 3697)
#        non-trivial merge - matches ( 2,  499) ( 3, 1641)
#                            track one ( 0,  265) ( 2,  499)
#                            track two ( 0,  659) ( 1,  301) ( 3, 1641)
#                            => ( 0,  659) ( 1,  301) ( 3, 1641) ( 0,  265) ( 2,  499)  - False
#        FOUND INCONSISTENT - ( 0,  659) ( 1,  301) ( 3, 1641) ( 0,  265) ( 2,  499)
#   327 tracks created
#    44 tracks in C extended with point in B
#    69 tracks in B extended with point in C
#   124 tracks merged (trivial)
#   124 tracks merged (non-trivial)
#    52 inconsistent tracks
# 30 tracks to resection
# 688 tracks to triangulate
# len(p_inA) = 30, len(c) = 30
# [2024-04-28T03:32:07Z WARN  re_sdk_comms::buffered_client] Dropping messages because tcp client has timed out.
# found 2 inliers out of 30
# Iterate over 9 views:
#  T_inB0_ofA has an initial value
#  T_inB1_ofA has an initial value and is an optimized key
#  T_inB2_ofA has an initial value and is an optimized key
#  T_inB3_ofA has an initial value and is an optimized key
# T_inB1_ofA has an sf_scale_residual factor
# Iterate over 1502 tracks:
#  track 0:
#   track_0_p_inA has an initial value and is an optimized key
#   track_0_b_0 has an initial value and an sf_projection_residual factor
#   track_0_b_1 has an initial value and an sf_projection_residual factor
#   track_0_b_3 has an initial value and an sf_projection_residual factor
#
#  ...
#
#  track 1501:
#   track_1501_p_inA has an initial value and is an optimized key
#   track_1501_b_2 has an initial value and an sf_projection_residual factor
#   track_1501_b_3 has an initial value and an sf_projection_residual factor
# [2024-04-27 22:32:19.071] [info] LM<sym::Optimize> [iter    0] lambda: 1.000e+00, error prev/linear/new: 2198.490/0.000/2143.283, rel reduction: 0.02511
# [2024-04-27 22:32:19.904] [info] LM<sym::Optimize> [iter    1] lambda: 1.000e-01, error prev/linear/new: 2143.283/0.000/2067.279, rel reduction: 0.03546
# [2024-04-27 22:32:20.766] [info] LM<sym::Optimize> [iter    2] lambda: 1.000e-02, error prev/linear/new: 2067.279/0.000/2042.687, rel reduction: 0.01190
# [2024-04-27 22:32:21.893] [info] LM<sym::Optimize> [iter    3] lambda: 1.000e-03, error prev/linear/new: 2042.687/0.000/2025.000, rel reduction: 0.00866
# [2024-04-27 22:32:23.836] [info] LM<sym::Optimize> [iter    4] lambda: 1.000e-04, error prev/linear/new: 2025.000/0.000/2009.143, rel reduction: 0.00783
# [2024-04-27 22:32:24.965] [info] LM<sym::Optimize> [iter    5] lambda: 1.000e-05, error prev/linear/new: 2009.143/0.000/1973.998, rel reduction: 0.01749
# [2024-04-27 22:32:26.151] [info] LM<sym::Optimize> [iter    6] lambda: 1.000e-06, error prev/linear/new: 1973.998/0.000/1931.414, rel reduction: 0.02157
# [2024-04-27 22:32:27.404] [info] LM<sym::Optimize> [iter    7] lambda: 1.000e-07, error prev/linear/new: 1931.414/0.000/1904.568, rel reduction: 0.01390
# [2024-04-27 22:32:28.528] [info] LM<sym::Optimize> [iter    8] lambda: 1.000e-08, error prev/linear/new: 1904.568/0.000/1894.647, rel reduction: 0.00521
# [2024-04-27 22:32:29.694] [info] LM<sym::Optimize> [iter    9] lambda: 1.000e-09, error prev/linear/new: 1894.647/0.000/1888.786, rel reduction: 0.00309
# [2024-04-27 22:32:31.212] [info] LM<sym::Optimize> [iter   10] lambda: 1.000e-10, error prev/linear/new: 1888.786/0.000/1886.336, rel reduction: 0.00130
# [2024-04-27 22:32:32.414] [info] LM<sym::Optimize> [iter   11] lambda: 1.000e-11, error prev/linear/new: 1886.336/0.000/1887.397, rel reduction: -0.00056
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 48
#      44 views_2_ini, tracks_2_ini = sfm.copy_results(views, tracks)
#      46 optimizer, initial_values = sfm.get_optimizer(views, tracks, K)
# ---> 48 result = optimizer.optimize(initial_values)
#      49 assert(result.status == symforce.opt.optimizer.Optimizer.Status.SUCCESS)
#      51 sfm.store_results(views, tracks, K, result, max_reprojection_err=max_reprojection_err)
#
# File ~/miniforge3/envs/ae598-3dv/lib/python3.10/site-packages/symforce/opt/optimizer.py:349, in Optimizer.optimize(self, initial_guess, **kwargs)
#     346 cc_values = self._cc_values(initial_guess)
#     348 try:
# --> 349     stats = self._cc_optimizer.optimize(cc_values, **kwargs)
#     350 except ZeroDivisionError as ex:
#     351     raise ZeroDivisionError("ERROR: Division by zero - check your use of epsilon!") from ex
#
# File ~/miniforge3/envs/ae598-3dv/lib/python3.10/site-packages/lcmtypes/sym/_index_entry_t.py:123, in index_entry_t.decode(data)
#     120 else:
#     121     buf = BytesIO(T.cast(bytes, data))
# --> 123 if buf.read(8) != index_entry_t._get_packed_fingerprint():
#     124     raise ValueError("Decode error")
#     125 return index_entry_t._decode_one(buf)
#
# KeyboardInterrupt:

# %%
import sfm
importlib.reload(sfm)
p_inA_temp = np.array([track['p_inA'] for track in tracks if track['valid'] and track['p_inA'] is not None])

P_in = sfm.remove_outliers(p_inA_temp)
a = P_in
a_ = p_inA_temp

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(a[:,0], a[:,1], a[:,2])
# ax.scatter(a_[:,0], a_[:,1], a_[:,2], s=8)
plt.show()

# %%
sfm.write_csv('P_switch.csv', a_)
# Out:
# [2024-04-28T03:29:01Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:29:01Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:29:01Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to EwResize
# [2024-04-28T03:29:01Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to EwResize
# [2024-04-28T03:29:01Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
# [2024-04-28T03:29:04Z WARN  winit::platform_impl::platform::wayland::window::state] Failed to set cursor to Default
